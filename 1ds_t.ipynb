# %% [markdown]
# Here, we generate the table that can be displayed in parallel.pdf

# %%
import json
import simplesimdb as database
import yaml
import numpy as np
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
#define conversion function 
def orderToString(x): 
    if np.isnan(x) : return 'n/a'
    return'%.2f'% x

def errorToString(x):
    return '%.2e' % x

# %%
# Create Database manger
db = database.Manager( directory = 'data_ds_t',
        filetype='yaml', executable='./execute.sh')
#db.delete_all()

# %%
# First generate some data
support=[1,10]
methods=["dg","linear", "cubic"]
resolution = [ (10,5), (16,10), (26,20), (40,40), (64,80) ]#, (100,160)]

# create simulation database
for method in methods :
    for m in support :
        for n in resolution :
            inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                "mx" : m, "my" : m, "method" : method }
            print( inputfile)
            db.create( inputfile, error="display")
# Out:
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'dg'}
# Existing simulation 912df4...29fd.yaml
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'dg'}
# Existing simulation 7772a5...52e4.yaml
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'dg'}
# Existing simulation f6abbf...b69d.yaml
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'dg'}
# Existing simulation 813722...5f99.yaml
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'dg'}
# Existing simulation 4a2eb4...524e.yaml
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'dg'}
# Existing simulation 2a7dae...c37b.yaml
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'dg'}
# Existing simulation c0b839...be27.yaml
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'dg'}
# Existing simulation c68edd...304e.yaml
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'dg'}
# Existing simulation cb2d52...0a61.yaml
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'dg'}
# Existing simulation 3464e1...2195.yaml
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'linear'}
# Existing simulation f270ea...ee45.yaml
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'linear'}
# Existing simulation adad7f...2fc1.yaml
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'linear'}
# Existing simulation 413ac5...be3d.yaml
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'linear'}
# Existing simulation a2322c...c544.yaml
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'linear'}
# Existing simulation a39689...e0b4.yaml
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'linear'}
# Existing simulation d8f411...c359.yaml
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'linear'}
# Existing simulation 510454...5167.yaml
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'linear'}
# Existing simulation 197c28...61fc.yaml
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'linear'}
# Existing simulation ae5dfa...92a1.yaml
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'linear'}
# Existing simulation bbbd9d...37bf.yaml
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'cubic'}
# Existing simulation 6ccf90...7cf9.yaml
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'cubic'}
# Existing simulation 5702a5...5712.yaml
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'cubic'}
# Existing simulation 609fb4...90a3.yaml
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'cubic'}
# Existing simulation 9c4919...c90a.yaml
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'cubic'}
# Existing simulation 41b1fd...d850.yaml
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'cubic'}
# Existing simulation f287d2...7f0d.yaml
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'cubic'}
# Existing simulation 2945b2...e4ff.yaml
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'cubic'}
# Existing simulation 415118...99f3.yaml
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'cubic'}
# Existing simulation ad5b72...641e.yaml
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'cubic'}
# Existing simulation 5119e7...4e84.yaml

# %%
content = db.table()
for entry in content:
    if entry["mx"] == 10 and entry["method"] == "linear":
        with open( db.outfile( entry) ) as f:
            output = yaml.full_load(f)
            print( output["Dirichlet"])
# Out:
# {'forward': 0.162826, 'backward': 0.162826, 'forward2': 0.0453438, 'backward2': 0.0453391, 'centered': 0.022759, 'centered_bc_along': 0.0220295, 'dss': 0.0695726, 'dss_bc_along': 0.0397168, 'divForward': 0.162847, 'divBackward': 0.162847, 'divCentered': 0.0227736, 'directLap': 0.0695815, 'directLap_bc_along': 0.0397214, 'invCenteredLap': 0.000450254}
# {'forward': 0.0414538, 'backward': 0.0414538, 'forward2': 0.00357042, 'backward2': 0.00357029, 'centered': 0.0018258, 'centered_bc_along': 0.00154688, 'dss': 0.0399528, 'dss_bc_along': 0.0308367, 'divForward': 0.0414591, 'divBackward': 0.0414591, 'divCentered': 0.00182664, 'directLap': 0.0399571, 'directLap_bc_along': 0.0308402, 'invCenteredLap': 0.000299973}
# {'forward': 0.321173, 'backward': 0.321173, 'forward2': 0.161445, 'backward2': 0.161445, 'centered': 0.0814336, 'centered_bc_along': 0.0793605, 'dss': 0.129235, 'dss_bc_along': 0.102762, 'divForward': 0.321218, 'divBackward': 0.321218, 'divCentered': 0.0814822, 'directLap': 0.129244, 'directLap_bc_along': 0.102747, 'invCenteredLap': 0.00108703}
# {'forward': 0.614105, 'backward': 0.614105, 'forward2': 0.510099, 'backward2': 0.510099, 'centered': 0.271982, 'centered_bc_along': 0.262592, 'dss': 0.242725, 'dss_bc_along': 0.239476, 'divForward': 0.614219, 'divBackward': 0.614219, 'divCentered': 0.272066, 'directLap': 0.242617, 'directLap_bc_along': 0.239311, 'invCenteredLap': 0.00255014}
# {'forward': 0.0821655, 'backward': 0.0821654, 'forward2': 0.0123117, 'backward2': 0.0123107, 'centered': 0.00634157, 'centered_bc_along': 0.00587039, 'dss': 0.0443385, 'dss_bc_along': 0.0228377, 'divForward': 0.0821762, 'divBackward': 0.0821761, 'divCentered': 0.0063453, 'directLap': 0.0443442, 'directLap_bc_along': 0.0228421, 'invCenteredLap': 0.000227676}

# %%
content = db.table()
df = pd.io.json.json_normalize(content)
df
# Out:
#     Nx  Ny  Nz  method  mx  my  n
# 0   64  64  80      dg  10  10  3
# 1   26  26  20  linear   1   1  3
# 2   10  10   5  linear   1   1  3
# 3   26  26  20  linear  10  10  3
# 4   40  40  40      dg   1   1  3
# 5   64  64  80  linear  10  10  3
# 6   10  10   5      dg   1   1  3
# 7   10  10   5   cubic  10  10  3
# 8   10  10   5      dg  10  10  3
# 9   26  26  20      dg   1   1  3
# 10  64  64  80  linear   1   1  3
# 11  64  64  80   cubic  10  10  3
# 12  16  16  10  linear   1   1  3
# 13  40  40  40   cubic  10  10  3
# 14  26  26  20      dg  10  10  3
# 15  10  10   5   cubic   1   1  3
# 2                   2.55e-03           2.66e-01            2.66e-01
# 3                   4.50e-04           2.38e-02            2.38e-02
# 4                   1.47e-04           6.20e-03            6.20e-03
# 5                   3.00e-04           1.92e-03            1.92e-03
# 6                   2.55e-03           2.62e-01            2.62e-01
# 7                   2.55e-03           2.62e-01            2.62e-01
# 8                   2.55e-03           2.62e-01            2.62e-01
# 9                   4.49e-04           2.28e-02            2.28e-02
# 10                  3.07e-04           2.10e-03            2.10e-03
# 11                  3.39e-05           1.62e-03            1.62e-03
# 12                  1.09e-03           8.23e-02            8.23e-02
# 13                  1.46e-04           6.19e-03            6.19e-03
# 14                  4.48e-04           2.28e-02            2.28e-02
# 15                  2.55e-03           2.62e-01            2.62e-01
# 16                  1.09e-03           8.01e-02            8.01e-02
# 17                  1.09e-03           8.01e-02            8.01e-02
# 18                  1.09e-03           8.01e-02            8.01e-02
# 19                  1.09e-03           8.23e-02            8.23e-02
# 20                  3.50e-05           1.62e-03            1.62e-03
# 21                  1.47e-04           6.19e-03            6.19e-03
# 22                       nan                nan                 nan
# 23                  1.47e-04           6.22e-03            6.22e-03
# 24                  4.49e-04           2.29e-02            2.29e-02
# 25                  4.49e-04           2.28e-02            2.28e-02
# 26                  2.55e-03           2.66e-01            2.66e-01
# 27                  2.35e-04           6.82e-03            6.82e-03
# 28                  2.28e-04           6.67e-03            6.67e-03
# 29                  1.09e-03           8.01e-02            8.01e-02
#
#     DirichletST.forward  DirichletST.backward
# 0              1.65e-03              1.65e-03
# 1              2.32e-02              2.32e-02
# 2              2.65e-01              2.65e-01
# 3              2.31e-02              2.31e-02
# 4              5.97e-03              5.97e-03
# 5              2.05e-03              2.05e-03
# 6              2.61e-01              2.61e-01
# 7              2.61e-01              2.61e-01
# 8              2.61e-01              2.61e-01
# 9              2.20e-02              2.20e-02
# 10             2.24e-03              2.24e-03
# 11             1.65e-03              1.65e-03
# 12             8.12e-02              8.12e-02
# 13             5.97e-03              5.97e-03
# 14             2.20e-02              2.20e-02
# 15             2.61e-01              2.61e-01
# 16             7.89e-02              7.89e-02
# 17             7.88e-02              7.88e-02
# 18             7.89e-02              7.89e-02
# 19             8.11e-02              8.11e-02
# 20             1.65e-03              1.65e-03
# 21             5.98e-03              5.98e-03
# 22                  nan                   nan
# 23             5.97e-03              5.97e-03
# 24             2.20e-02              2.20e-02
# 25             2.20e-02              2.20e-02
# 26             2.65e-01              2.65e-01
# 27             6.80e-03              6.80e-03
# 28             6.60e-03              6.60e-03
# 29             7.89e-02              7.89e-02
#
# [30 rows x 39 columns]

# %% [markdown]
# Now we compute the order of the schemes for given boundary condition and m and change the header to something nice

# %%
names = ["centered", "directLap", "divCentered", "invCenteredLap"]
#names = ["centered_bc_along", "dss_bc_along", "divCentered", "invCenteredLap"]

dflist = []
string_dflist = []
for bc in ["Dirichlet", "Neumann"]:
    columns = []
    for name in names :
        columns.append( bc+"."+name)
    for method in ["dg", "linear", "cubic"]:
        for m in [1,10]:
            df_dir = df[["method", "mx", "Nx", "Nz"]+columns]
            df_dir = df_dir.loc [ df_dir["mx"]==m]
            df_dir = df_dir.loc[ df_dir["method"] == method]
            df_dir = df_dir.sort_values( by=['mx','Nx','Nz']) # sort
            for name in names:
                df_dir.insert(df_dir.columns.get_loc(bc+"."+name)+1,column="order."+name, value=df_dir.loc[:,bc+"."+name])
                df_dir["order."+name] = (np.log ( df_dir["order."+name]/ df_dir["order."+name].shift(1))/
                    np.log( df_dir["Nz"].shift(1)/df_dir["Nz"]))
            df_dir.set_index(['method','mx','Nx','Nz'], inplace=True)
            headers = [ "$\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}",
                        "$\Delta_\parallel$ Eq.~\eqref{eq:second_order}",
                        "$\nabla \cdot ( {\mathbf{\hat b}} f)$",
                        "$(1-\Delta_\parallel)^{-1} f$"]
            df_dir.columns=pd.MultiIndex.from_product([headers,["error", "order"] ])
            dflist.append(df_dir)
            #We would like the order to be displayed differently.
            #In pandas we must convert the columns to strings to do that.
            string_df_dir = df_dir.copy()
            for header in headers :
                string_df_dir[header, "error"]=string_df_dir[header, "error"].apply( errorToString)
                string_df_dir[header, "order"]=string_df_dir[header, "order"].apply( orderToString)
            string_dflist.append(string_df_dir)

# %%
string_dflist[0]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# dg     1  10 5                                       2.70e-01   n/a
#           16 10                                      8.05e-02  1.75
#           26 20                                      2.23e-02  1.85
#           40 40                                      6.09e-03  1.87
#           64 80                                      1.69e-03  1.85
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# dg     1  10 5                                        2.43e-01   n/a
#           16 10                                       1.29e-01  0.91
#           26 20                                       6.90e-02  0.91
#           40 40                                       4.01e-02  0.78
#           64 80                                       2.54e-02  0.66
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# dg     1  10 5                               2.70e-01   n/a
#           16 10                              8.05e-02  1.75
#           26 20                              2.23e-02  1.85
#           40 40                              6.10e-03  1.87
#           64 80                              1.69e-03  1.85
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error order
# method mx Nx Nz
# dg     1  10 5                       2.55e-03   n/a
#           16 10                      1.09e-03  1.23
#           26 20                      4.49e-04  1.28
#           40 40                      1.47e-04  1.61
#           64 80                      3.50e-05  2.07

# %%
string_dflist[1]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# dg     10 10 5                                       2.70e-01   n/a
#           16 10                                      8.05e-02  1.75
#           26 20                                      2.23e-02  1.85
#           40 40                                      6.09e-03  1.87
#           64 80                                      1.69e-03  1.85
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# dg     10 10 5                                        2.43e-01   n/a
#           16 10                                       1.29e-01  0.91
#           26 20                                       6.90e-02  0.91
#           40 40                                       4.00e-02  0.79
#           64 80                                       2.53e-02  0.66
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# dg     10 10 5                               2.70e-01   n/a
#           16 10                              8.05e-02  1.75
#           26 20                              2.23e-02  1.85
#           40 40                              6.10e-03  1.87
#           64 80                              1.69e-03  1.85
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error order
# method mx Nx Nz
# dg     10 10 5                       2.55e-03   n/a
#           16 10                      1.09e-03  1.23
#           26 20                      4.48e-04  1.28
#           40 40                      1.47e-04  1.61
#           64 80                      3.46e-05  2.08

# %%
string_dflist[2]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# linear 1  10 5                                       2.72e-01   n/a
#           16 10                                      8.14e-02  1.74
#           26 20                                      2.28e-02  1.84
#           40 40                                      6.41e-03  1.83
#           64 80                                      1.92e-03  1.74
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# linear 1  10 5                                        2.43e-01   n/a
#           16 10                                       1.30e-01  0.91
#           26 20                                       7.00e-02  0.89
#           40 40                                       4.58e-02  0.61
#           64 80                                       4.27e-02  0.10
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# linear 1  10 5                               2.72e-01   n/a
#           16 10                              8.15e-02  1.74
#           26 20                              2.28e-02  1.84
#           40 40                              6.41e-03  1.83
#           64 80                              1.92e-03  1.74
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error  order
# method mx Nx Nz
# linear 1  10 5                       2.55e-03    n/a
#           16 10                      1.09e-03   1.23
#           26 20                      4.53e-04   1.26
#           40 40                      2.35e-04   0.95
#           64 80                      3.07e-04  -0.38

# %%
string_dflist[3]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# linear 10 10 5                                       2.72e-01   n/a
#           16 10                                      8.14e-02  1.74
#           26 20                                      2.28e-02  1.84
#           40 40                                      6.34e-03  1.84
#           64 80                                      1.83e-03  1.80
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# linear 10 10 5                                        2.43e-01   n/a
#           16 10                                       1.29e-01  0.91
#           26 20                                       6.96e-02  0.89
#           40 40                                       4.43e-02  0.65
#           64 80                                       4.00e-02  0.15
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# linear 10 10 5                               2.72e-01   n/a
#           16 10                              8.15e-02  1.74
#           26 20                              2.28e-02  1.84
#           40 40                              6.35e-03  1.84
#           64 80                              1.83e-03  1.80
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error  order
# method mx Nx Nz
# linear 10 10 5                       2.55e-03    n/a
#           16 10                      1.09e-03   1.23
#           26 20                      4.50e-04   1.27
#           40 40                      2.28e-04   0.98
#           64 80                      3.00e-04  -0.40

# %%
string_dflist[4]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# cubic  1  10 5                                       2.70e-01   n/a
#           16 10                                      8.05e-02  1.75
#           26 20                                      2.23e-02  1.85
#           40 40                                      6.09e-03  1.87
#           64 80                                           nan   n/a
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# cubic  1  10 5                                        2.43e-01   n/a
#           16 10                                       1.29e-01  0.91
#           26 20                                       6.90e-02  0.91
#           40 40                                       4.00e-02  0.78
#           64 80                                            nan   n/a
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# cubic  1  10 5                               2.70e-01   n/a
#           16 10                              8.05e-02  1.75
#           26 20                              2.23e-02  1.85
#           40 40                              6.10e-03  1.87
#           64 80                                   nan   n/a
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error order
# method mx Nx Nz
# cubic  1  10 5                       2.55e-03   n/a
#           16 10                      1.09e-03  1.23
#           26 20                      4.49e-04  1.28
#           40 40                      1.47e-04  1.61
#           64 80                           nan   n/a

# %%
string_dflist[5]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# cubic  10 10 5                                       2.70e-01   n/a
#           16 10                                      8.05e-02  1.75
#           26 20                                      2.23e-02  1.85
#           40 40                                      6.09e-03  1.87
#           64 80                                      1.69e-03  1.85
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# cubic  10 10 5                                        2.43e-01   n/a
#           16 10                                       1.29e-01  0.91
#           26 20                                       6.90e-02  0.91
#           40 40                                       4.00e-02  0.79
#           64 80                                       2.53e-02  0.66
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# cubic  10 10 5                               2.70e-01   n/a
#           16 10                              8.05e-02  1.75
#           26 20                              2.23e-02  1.85
#           40 40                              6.10e-03  1.87
#           64 80                              1.69e-03  1.85
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error order
# method mx Nx Nz
# cubic  10 10 5                       2.55e-03   n/a
#           16 10                      1.09e-03  1.23
#           26 20                      4.49e-04  1.28
#           40 40                      1.46e-04  1.62
#           64 80                      3.39e-05  2.11

# %% [markdown]
# It seems that
# - for Dirichlet bc and perp implementation the 2nd order derivative has only 1st order convergence
# - for Dirichlet bc and along field implementation the 2nd order derivative has 2nd order convergence
#
# this could be because of  how the test function looks outside the domain

# %%
string_dflist[6]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# dg     1  10 5                                       2.70e-01   n/a
#           16 10                                      8.21e-02  1.72
#           26 20                                      2.27e-02  1.86
#           40 40                                      5.86e-03  1.95
#           64 80                                      1.48e-03  1.99
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# dg     1  10 5                                        2.46e-01   n/a
#           16 10                                       1.16e-01  1.09
#           26 20                                       3.67e-02  1.66
#           40 40                                       9.80e-03  1.91
#           64 80                                       2.53e-03  1.95
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# dg     1  10 5                               2.70e-01   n/a
#           16 10                              8.21e-02  1.72
#           26 20                              2.27e-02  1.86
#           40 40                              5.87e-03  1.95
#           64 80                              1.48e-03  1.99
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error order
# method mx Nx Nz
# dg     1  10 5                       2.67e-03   n/a
#           16 10                      1.15e-03  1.21
#           26 20                      3.37e-04  1.77
#           40 40                      8.64e-05  1.97
#           64 80                      2.16e-05  2.00

# %%
string_dflist[7]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# dg     10 10 5                                       2.70e-01   n/a
#           16 10                                      8.21e-02  1.72
#           26 20                                      2.27e-02  1.86
#           40 40                                      5.86e-03  1.95
#           64 80                                      1.48e-03  1.99
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# dg     10 10 5                                        2.46e-01   n/a
#           16 10                                       1.16e-01  1.09
#           26 20                                       3.67e-02  1.66
#           40 40                                       9.79e-03  1.91
#           64 80                                       2.50e-03  1.97
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# dg     10 10 5                               2.70e-01   n/a
#           16 10                              8.21e-02  1.72
#           26 20                              2.27e-02  1.86
#           40 40                              5.87e-03  1.95
#           64 80                              1.48e-03  1.99
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error order
# method mx Nx Nz
# dg     10 10 5                       2.67e-03   n/a
#           16 10                      1.15e-03  1.21
#           26 20                      3.37e-04  1.77
#           40 40                      8.64e-05  1.97
#           64 80                      2.16e-05  2.00

# %%
string_dflist[8]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# linear 1  10 5                                       2.72e-01   n/a
#           16 10                                      8.33e-02  1.71
#           26 20                                      2.32e-02  1.84
#           40 40                                      6.16e-03  1.91
#           64 80                                      1.69e-03  1.87
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}         \
#                                                          error  order
# method mx Nx Nz
# linear 1  10 5                                        2.47e-01    n/a
#           16 10                                       1.16e-01   1.09
#           26 20                                       3.75e-02   1.63
#           40 40                                       2.33e-02   0.68
#           64 80                                       3.43e-02  -0.56
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# linear 1  10 5                               2.72e-01   n/a
#           16 10                              8.33e-02  1.71
#           26 20                              2.32e-02  1.84
#           40 40                              6.17e-03  1.91
#           64 80                              1.69e-03  1.87
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error  order
# method mx Nx Nz
# linear 1  10 5                       2.67e-03    n/a
#           16 10                      1.15e-03   1.22
#           26 20                      3.43e-04   1.75
#           40 40                      2.15e-04   0.67
#           64 80                      3.18e-04  -0.57

# %%
string_dflist[9]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# linear 10 10 5                                       2.72e-01   n/a
#           16 10                                      8.33e-02  1.71
#           26 20                                      2.32e-02  1.84
#           40 40                                      6.12e-03  1.92
#           64 80                                      1.62e-03  1.92
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}         \
#                                                          error  order
# method mx Nx Nz
# linear 10 10 5                                        2.47e-01    n/a
#           16 10                                       1.16e-01   1.09
#           26 20                                       3.69e-02   1.65
#           40 40                                       2.15e-02   0.78
#           64 80                                       3.20e-02  -0.57
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# linear 10 10 5                               2.72e-01   n/a
#           16 10                              8.33e-02  1.71
#           26 20                              2.32e-02  1.84
#           40 40                              6.13e-03  1.92
#           64 80                              1.62e-03  1.92
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error  order
# method mx Nx Nz
# linear 10 10 5                       2.67e-03    n/a
#           16 10                      1.15e-03   1.22
#           26 20                      3.40e-04   1.76
#           40 40                      2.09e-04   0.70
#           64 80                      3.12e-04  -0.58

# %%
string_dflist[10]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# cubic  1  10 5                                       2.70e-01   n/a
#           16 10                                      8.21e-02  1.72
#           26 20                                      2.27e-02  1.86
#           40 40                                      5.86e-03  1.95
#           64 80                                           nan   n/a
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# cubic  1  10 5                                        2.46e-01   n/a
#           16 10                                       1.16e-01  1.09
#           26 20                                       3.67e-02  1.66
#           40 40                                       9.78e-03  1.91
#           64 80                                            nan   n/a
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# cubic  1  10 5                               2.70e-01   n/a
#           16 10                              8.21e-02  1.72
#           26 20                              2.27e-02  1.86
#           40 40                              5.87e-03  1.95
#           64 80                                   nan   n/a
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error order
# method mx Nx Nz
# cubic  1  10 5                       2.67e-03   n/a
#           16 10                      1.15e-03  1.21
#           26 20                      3.37e-04  1.77
#           40 40                      8.64e-05  1.97
#           64 80                           nan   n/a

# %%
string_dflist[11]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# cubic  10 10 5                                       2.70e-01   n/a
#           16 10                                      8.21e-02  1.72
#           26 20                                      2.27e-02  1.86
#           40 40                                      5.86e-03  1.95
#           64 80                                      1.48e-03  1.99
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# cubic  10 10 5                                        2.46e-01   n/a
#           16 10                                       1.16e-01  1.09
#           26 20                                       3.67e-02  1.66
#           40 40                                       9.78e-03  1.91
#           64 80                                       2.49e-03  1.98
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# cubic  10 10 5                               2.70e-01   n/a
#           16 10                              8.21e-02  1.72
#           26 20                              2.27e-02  1.86
#           40 40                              5.87e-03  1.95
#           64 80                              1.48e-03  1.99
#
#                 $(1-\Delta_\parallel)^{-1} f$
#                                         error order
# method mx Nx Nz
# cubic  10 10 5                       2.67e-03   n/a
#           16 10                      1.15e-03  1.21
#           26 20                      3.37e-04  1.77
#           40 40                      8.64e-05  1.97
#           64 80                      2.16e-05  2.00

# %%
filename='ds_cylindrical_dirichlet'+str(m)+'.tex'
with open(filename, 'wb') as f:
    f.write(bytes(df_dir.to_latex(
        escape=False,column_format='llllp{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}',
                               bold_rows=True),'UTF-8'))
