# %% [markdown]
# Here, we generate the table that can be displayed in parallel.pdf

# %%
import json
import simplesimdb as database
import yaml
import numpy as np
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
# Create Database manger
db = database.Manager( directory = 'data_ds_t',
        filetype='yaml', executable='./execute.sh')
#db.delete_all()

# %%
# First generate some data
support=[1,10]
methods=["dg","linear", "cubic"]
resolution = [ (10,5), (16,10), (26,20), (40,40), (64,80) ]#, (100,160)]

# create simulation database
for method in methods :
    for m in support :
        for n in resolution :
            inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                "mx" : m, "my" : m, "method" : method }
            print( inputfile)
#             db.delete( inputfile)
            db.create( inputfile, error="display")
# Out:
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'cubic'}

# %%
content = db.table()
for entry in content:
    if entry["mx"] == 10 and entry["method"] == "linear":
        with open( db.outfile( entry) ) as f:
            output = yaml.full_load(f)
            print( output["Dirichlet"])
# Out:
# {'forward': 0.16284, 'backward': 0.16284, 'forward2': 0.0454002, 'backward2': 0.0453955, 'centered': 0.022762, 'dss': 0.0695748, 'centered_bc_along': 0.0220327, 'dss_bc_along': 0.0397187, 'divForward': 0.543281, 'divBackward': 0.543281, 'divCentered': 0.162105, 'divDirectForward': 0.162824, 'divDirectBackward': 0.162824, 'divDirectCentered': 0.0227586, 'forwardLap': 0.126183, 'backwardLap': 0.126183, 'centeredLap': 0.20126, 'directLap': 0.0695901, 'directLap_bc_along': 0.0397335, 'invForwardLap': 0.000851673, 'invBackwardLap': 0.000851673, 'invCenteredLap': 0.00189077}
# {'forward': 0.0414574, 'backward': 0.0414574, 'forward2': 0.0036143, 'backward2': 0.00361426, 'centered': 0.0018259, 'dss': 0.0399527, 'centered_bc_along': 0.00154698, 'dss_bc_along': 0.0308364, 'divForward': 2.07159, 'divBackward': 2.07159, 'divCentered': 0.164046, 'divDirectForward': 0.0414533, 'divDirectBackward': 0.0414533, 'divDirectCentered': 0.00182568, 'forwardLap': 0.0869103, 'backwardLap': 0.0869103, 'centeredLap': 0.167375, 'directLap': 0.0399565, 'directLap_bc_along': 0.0308392, 'invForwardLap': 0.000374398, 'invBackwardLap': 0.000374398, 'invCenteredLap': 0.00142924}
# {'forward': 0.614164, 'backward': 0.614164, 'forward2': 0.510263, 'backward2': 0.510263, 'centered': 0.27209, 'dss': 0.242807, 'centered_bc_along': 0.262697, 'dss_bc_along': 0.239563, 'divForward': 0.623669, 'divBackward': 0.623669, 'divCentered': 0.290856, 'divDirectForward': 0.614103, 'divDirectBackward': 0.614103, 'divDirectCentered': 0.272016, 'forwardLap': 0.607795, 'backwardLap': 0.607795, 'centeredLap': 0.736021, 'directLap': 0.24296, 'directLap_bc_along': 0.239677, 'invForwardLap': 0.00272205, 'invBackwardLap': 0.00272205, 'invCenteredLap': 0.00517034}
# {'forward': 0.0821727, 'backward': 0.0821727, 'forward2': 0.0123628, 'backward2': 0.012362, 'centered': 0.00634212, 'dss': 0.0443384, 'centered_bc_along': 0.00587093, 'dss_bc_along': 0.0228369, 'divForward': 1.03914, 'divBackward': 1.03914, 'divCentered': 0.162721, 'divDirectForward': 0.0821645, 'divDirectBackward': 0.0821645, 'divDirectCentered': 0.00634125, 'forwardLap': 0.0939546, 'backwardLap': 0.0939546, 'centeredLap': 0.171665, 'directLap': 0.0443438, 'directLap_bc_along': 0.0228404, 'invForwardLap': 0.000599956, 'invBackwardLap': 0.000599956, 'invCenteredLap': 0.00164086}
# {'forward': 0.321202, 'backward': 0.321201, 'forward2': 0.161515, 'backward2': 0.161514, 'centered': 0.0814487, 'dss': 0.129251, 'centered_bc_along': 0.0793812, 'dss_bc_along': 0.10278, 'divForward': 0.412199, 'divBackward': 0.412199, 'divCentered': 0.172481, 'divDirectForward': 0.32117, 'divDirectBackward': 0.321169, 'divDirectCentered': 0.0814383, 'forwardLap': 0.252313, 'backwardLap': 0.252313, 'centeredLap': 0.341368, 'directLap': 0.129311, 'directLap_bc_along': 0.102831, 'invForwardLap': 0.00132629, 'invBackwardLap': 0.00132629, 'invCenteredLap': 0.00283226}

# 8             6.22e-03             5.97e-03              5.97e-03
# 9             2.28e-02             2.20e-02              2.20e-02
# 10            1.62e-03             1.65e-03              1.65e-03
# 11            1.62e-03             1.65e-03              1.65e-03
# 12            2.38e-02             2.31e-02              2.31e-02
# 13            2.66e-01             2.65e-01              2.65e-01
# 14            1.92e-03             2.05e-03              2.05e-03
# 15            6.82e-03             6.80e-03              6.80e-03
# 16            2.28e-02             2.20e-02              2.20e-02
# 17            8.23e-02             8.12e-02              8.12e-02
# 18            2.66e-01             2.65e-01              2.65e-01
# 19            2.29e-02             2.20e-02              2.20e-02
# 20            2.28e-02             2.20e-02              2.20e-02
# 21            6.19e-03             5.97e-03              5.97e-03
# 22            1.62e-03             1.65e-03              1.65e-03
# 23            6.67e-03             6.60e-03              6.60e-03
# 24            8.23e-02             8.11e-02              8.11e-02
# 25            6.20e-03             5.97e-03              5.97e-03
# 26            8.01e-02             7.88e-02              7.88e-02
# 27            1.62e-03             1.65e-03              1.65e-03
# 28            8.01e-02             7.89e-02              7.89e-02
# 29            2.38e-02             2.32e-02              2.32e-02
#
# [30 rows x 55 columns]

# %% [markdown]
# Now we compute the order of the schemes for given boundary condition and m and change the header to something nice

# %%
# bc = "Dirichlet"
bc = "Neumann"
m = 10
method = "linear"
names = ["centered", "dss", "divCentered", "invCenteredLap"]
#names = ["centered_bc_along", "dss_bc_along", "divCentered", "invCenteredLap"]
columns = []
for name in names :
    columns.append( bc+"."+name)
df_dir = df[["method", "mx", "Nx", "Nz"]+columns]
df_dir = df_dir.loc [ df_dir["mx"]==m]
df_dir = df_dir.loc[ df_dir["method"] == method]
df_dir = df_dir.sort_values( by=['mx','Nx','Nz']) # sort
for name in names:
    df_dir.insert(df_dir.columns.get_loc(bc+"."+name)+1,column="order."+name, value=df_dir.loc[:,bc+"."+name])
    df_dir["order."+name] = (np.log ( df_dir["order."+name]/ df_dir["order."+name].shift(1))/
        np.log( df_dir["Nz"].shift(1)/df_dir["Nz"]))
df_dir.set_index(['method','mx','Nx','Nz'], inplace=True)
headers = [ "$\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}",
            "$\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}",
            "$\nabla \cdot ( {\mathbf{\hat b}} f)$",
            "$\Delta_\parallel^{-1} f$"]
df_dir.columns=pd.MultiIndex.from_product([headers,["error", "order"] ])
df_dir
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}           \
#                                                         error    order
# method mx Nx Nz
# linear 10 10 5                                       2.72e-01      nan
#           16 10                                      8.33e-02 1.71e+00
#           26 20                                      2.32e-02 1.84e+00
#           40 40                                      6.12e-03 1.92e+00
#           64 80                                      1.62e-03 1.92e+00
#
#                 $\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}            \
#                                                            error     order
# method mx Nx Nz
# linear 10 10 5                                          2.47e-01       nan
#           16 10                                         1.16e-01  1.09e+00
#           26 20                                         3.69e-02  1.65e+00
#           40 40                                         2.15e-02  7.82e-01
#           64 80                                         3.20e-02 -5.74e-01
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$            \
#                                                 error     order
# method mx Nx Nz
# linear 10 10 5                               2.92e-01       nan
#           16 10                              1.73e-01  7.57e-01
#           26 20                              1.62e-01  8.96e-02
#           40 40                              1.63e-01 -5.30e-03
#           64 80                              1.64e-01 -1.16e-02
#
#                 $\Delta_\parallel^{-1} f$
#                                     error    order
# method mx Nx Nz
# linear 10 10 5                   5.21e-03      nan
#           16 10                  2.86e-03 8.66e-01
#           26 20                  1.89e-03 5.99e-01
#           40 40                  1.62e-03 2.18e-01
#           64 80                  1.42e-03 1.89e-01

# %% [markdown]
# It seems that
# - for Dirichlet bc and perp implementation the 2nd order derivative has only 1st order convergence
# - for Dirichlet bc and along field implementation the 2nd order derivative has 2nd order convergence
#
# this could be because of  how the test function looks outside the domain

# %% [markdown]
# We would like the order to be displayed differently.
# In pandas we must convert the columns to strings to do that.

# %%
#define conversion function 
def orderToString(x): 
    if np.isnan(x) : return 'n/a'
    return'%.2f'% x

def errorToString(x):
    return '%.2e' % x

# %%
string_df_dir = df_dir
for header in headers :  
    string_df_dir[header, "error"]=string_df_dir[header, "error"].apply( errorToString)
    string_df_dir[header, "order"]=string_df_dir[header, "order"].apply( orderToString)
string_df_dir
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# linear 10 10 5                                       2.72e-01   n/a
#           16 10                                      8.33e-02  1.71
#           26 20                                      2.32e-02  1.84
#           40 40                                      6.12e-03  1.92
#           64 80                                      1.62e-03  1.92
#
#                 $\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}         \
#                                                            error  order
# method mx Nx Nz
# linear 10 10 5                                          2.47e-01    n/a
#           16 10                                         1.16e-01   1.09
#           26 20                                         3.69e-02   1.65
#           40 40                                         2.15e-02   0.78
#           64 80                                         3.20e-02  -0.57
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$         \
#                                                 error  order
# method mx Nx Nz
# linear 10 10 5                               2.92e-01    n/a
#           16 10                              1.73e-01   0.76
#           26 20                              1.62e-01   0.09
#           40 40                              1.63e-01  -0.01
#           64 80                              1.64e-01  -0.01
#
#                 $\Delta_\parallel^{-1} f$
#                                     error order
# method mx Nx Nz
# linear 10 10 5                   5.21e-03   n/a
#           16 10                  2.86e-03  0.87
#           26 20                  1.89e-03  0.60
#           40 40                  1.62e-03  0.22
#           64 80                  1.42e-03  0.19

# %%
filename='ds_cylindrical_dirichlet'+str(m)+'.tex'
with open(filename, 'wb') as f:
    f.write(bytes(df_dir.to_latex(
        escape=False,column_format='llllp{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}',
                               bold_rows=True),'UTF-8'))
