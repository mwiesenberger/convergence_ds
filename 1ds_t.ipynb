# %% [markdown]
# Here, we generate the table that can be displayed in parallel.pdf

# %%
import json
import simplesimdb as database
import yaml
import numpy as np
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
# Create Database manger
db = database.Manager( directory = 'data_ds_t', filetype='yaml',
        executable='./execute.sh')

# %%
support=[1,10]
resolution = [ (10,5), (16,10), (26,20), (40,40), (64,80), (100,160)]

# create simulation database
for m in support :
    for n in resolution :
        inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                "mx" : m, "my" : m }
        db.create( inputfile)

# %%
content = db.table()
for entry in content:
    if entry["mx"] == 10 :
        with open( db.outfile( entry) ) as f:
            output = yaml.full_load(f)
            print( output["Dirichlet"])
# Out:
# {'forward': 0.040569, 'backward': 0.040569, 'centered': 0.00168765, 'dss': 0.0253435, 'divForward': 0.458741, 'divBackward': 0.458741, 'divCentered': 0.346162, 'divDirectForward': 0.0405649, 'divDirectBackward': 0.0405649, 'divDirectCentered': 0.00168748, 'forwardLap': 0.337215, 'backwardLap': 0.337215, 'centeredLap': 0.337663, 'directLap': 0.025346, 'invForwardLap': 0.000101422, 'invBackwardLap': 0.000101422, 'invCenteredLap': 0.00021455}
# {'forward': 0.16155, 'backward': 0.16155, 'centered': 0.0222969, 'dss': 0.0689589, 'divForward': 0.16678, 'divBackward': 0.16678, 'divCentered': 0.0374395, 'divDirectForward': 0.161533, 'divDirectBackward': 0.161533, 'divDirectCentered': 0.0222947, 'forwardLap': 0.107815, 'backwardLap': 0.107815, 'centeredLap': 0.140387, 'directLap': 0.0689744, 'invForwardLap': 0.000418456, 'invBackwardLap': 0.000418456, 'invCenteredLap': 0.00102099}
# {'forward': 0.6127, 'backward': 0.6127, 'centered': 0.27013, 'dss': 0.243075, 'divForward': 0.608595, 'divBackward': 0.608595, 'divCentered': 0.261347, 'divDirectForward': 0.612639, 'divDirectBackward': 0.612639, 'divDirectCentered': 0.270103, 'forwardLap': 0.619445, 'backwardLap': 0.619445, 'centeredLap': 0.746583, 'directLap': 0.243228, 'invForwardLap': 0.00262423, 'invBackwardLap': 0.00262423, 'invCenteredLap': 0.0050694}
# {'forward': 0.319633, 'backward': 0.319633, 'centered': 0.0804658, 'dss': 0.129279, 'divForward': 0.318958, 'divBackward': 0.318958, 'divCentered': 0.0800309, 'divDirectForward': 0.319601, 'divDirectBackward': 0.319601, 'divDirectCentered': 0.0804578, 'forwardLap': 0.251108, 'backwardLap': 0.251108, 'centeredLap': 0.327024, 'directLap': 0.129339, 'invForwardLap': 0.00107082, 'invBackwardLap': 0.00107082, 'invCenteredLap': 0.00243916}
# {'forward': 0.020292, 'backward': 0.020292, 'centered': 0.000484273, 'dss': 0.0168443, 'divForward': 1.1118, 'divBackward': 1.1118, 'divCentered': 0.980884, 'divDirectForward': 0.0202899, 'divDirectBackward': 0.0202899, 'divDirectCentered': 0.000484225, 'forwardLap': 0.953326, 'backwardLap': 0.953326, 'centeredLap': 0.952899, 'directLap': 0.0168459, 'invForwardLap': 0.000160033, 'invBackwardLap': 0.000160033, 'invCenteredLap': 0.00018947}
# {'forward': 0.0810497, 'backward': 0.0810497, 'centered': 0.00609204, 'dss': 0.0400024, 'divForward': 0.139683, 'divBackward': 0.139683, 'divCentered': 0.0780946, 'divDirectForward': 0.0810417, 'divDirectBackward': 0.0810417, 'divDirectCentered': 0.00609144, 'forwardLap': 0.0916094, 'backwardLap': 0.0916094, 'centeredLap': 0.0999803, 'directLap': 0.0400075, 'invForwardLap': 0.000141042, 'invBackwardLap': 0.000141042, 'invCenteredLap': 0.000415781}

# %%
content = db.table()
df = pd.json_normalize(content)
df
# Out:
#      Nx   Ny   Nz  mx  my  n
# 0    64   64   80  10  10  3
# 1    26   26   20  10  10  3
# 2    10   10    5  10  10  3
# 3    26   26   20   1   1  3
# 4    10   10    5   1   1  3
# 5    40   40   40   1   1  3
# 6    16   16   10  10  10  3
# 7    16   16   10   1   1  3
# 8   100  100  160  10  10  3
# 9   100  100  160   1   1  3
# 10   64   64   80   1   1  3
# 11   40   40   40  10  10  3

# %%
table=list()
for data in content :
    with open( db.outfile( data)) as f:
        output = yaml.full_load(f)
        table.append( output)
df = pd.json_normalize(table)
df
# Out:
#     n   Nx   Ny   Nz  mx  my  Neumann.forward  Neumann.backward  \
# 0   3   64   64   80  10  10         4.06e-02          4.06e-02
# 1   3   26   26   20  10  10         1.62e-01          1.62e-01
# 2   3   10   10    5  10  10         6.13e-01          6.13e-01
# 3   3   26   26   20   1   1         1.62e-01          1.62e-01
# 4   3   10   10    5   1   1         6.13e-01          6.13e-01
# 5   3   40   40   40   1   1         8.11e-02          8.11e-02
# 6   3   16   16   10  10  10         3.20e-01          3.20e-01
# 7   3   16   16   10   1   1         3.20e-01          3.20e-01
# 8   3  100  100  160  10  10         2.03e-02          2.03e-02
# 9   3  100  100  160   1   1         2.03e-02          2.03e-02
# 10  3   64   64   80   1   1         4.06e-02          4.06e-02
# 11  3   40   40   40  10  10         8.11e-02          8.11e-02
#
#     Neumann.centered  Neumann.dss  ...  Dirichlet.divDirectForward  \
# 0           1.48e-03     2.50e-03  ...                    4.06e-02
# 1           2.27e-02     3.67e-02  ...                    1.62e-01
# 2           2.70e-01     2.47e-01  ...                    6.13e-01
# 3           2.27e-02     3.67e-02  ...                    1.62e-01
# 4           2.70e-01     2.47e-01  ...                    6.13e-01
# 5           5.86e-03     9.80e-03  ...                    8.10e-02
# 6           8.21e-02     1.16e-01  ...                    3.20e-01
# 7           8.21e-02     1.16e-01  ...                    3.20e-01
# 8           3.71e-04     6.86e-04  ...                    2.03e-02
# 9           3.71e-04     7.75e-04  ...                    2.03e-02
# 10          1.48e-03     2.53e-03  ...                    4.06e-02
# 11          5.86e-03     9.79e-03  ...                    8.10e-02
#
#     Dirichlet.divDirectBackward  Dirichlet.divDirectCentered  \
# 0                      4.06e-02                     1.69e-03
# 1                      1.62e-01                     2.23e-02
# 2                      6.13e-01                     2.70e-01
# 3                      1.62e-01                     2.23e-02
# 4                      6.13e-01                     2.70e-01
# 5                      8.10e-02                     6.09e-03
# 6                      3.20e-01                     8.05e-02
# 7                      3.20e-01                     8.05e-02
# 8                      2.03e-02                     4.84e-04
# 9                      2.03e-02                     4.85e-04
# 10                     4.06e-02                     1.69e-03
# 11                     8.10e-02                     6.09e-03
#
#     Dirichlet.forwardLap  Dirichlet.backwardLap  Dirichlet.centeredLap  \
# 0               3.37e-01               3.37e-01               3.38e-01
# 1               1.08e-01               1.08e-01               1.40e-01
# 2               6.19e-01               6.19e-01               7.47e-01
# 3               1.37e+00               1.37e+00               1.35e+00
# 4               7.01e-01               7.01e-01               7.88e-01
# 5               2.95e+00               2.95e+00               2.92e+00
# 6               2.51e-01               2.51e-01               3.27e-01
# 7               7.13e-01               7.13e-01               7.00e-01
# 8               9.53e-01               9.53e-01               9.53e-01
# 9               1.19e+01               1.19e+01               1.19e+01
# 10              6.18e+00               6.18e+00               6.16e+00
# 11              9.16e-02               9.16e-02               1.00e-01
#
#     Dirichlet.directLap  Dirichlet.invForwardLap  Dirichlet.invBackwardLap  \
# 0              2.53e-02                 1.01e-04                  1.01e-04
# 1              6.90e-02                 4.18e-04                  4.18e-04
# 2              2.43e-01                 2.62e-03                  2.62e-03
# 3              6.90e-02                 3.49e-03                  3.49e-03
# 4              2.43e-01                 2.66e-03                  2.66e-03
# 5              4.01e-02                 2.42e-03                  2.42e-03
# 6              1.29e-01                 1.07e-03                  1.07e-03
# 7              1.29e-01                 2.36e-03                  2.36e-03
# 8              1.68e-02                 1.60e-04                  1.60e-04
# 9              1.69e-02                 1.72e-03                  1.72e-03
# 10             2.54e-02                 1.76e-03                  1.76e-03
# 11             4.00e-02                 1.41e-04                  1.41e-04
#
#     Dirichlet.invCenteredLap
# 0                   2.15e-04
# 1                   1.02e-03
# 2                   5.07e-03
# 3                   4.04e-03
# 4                   5.08e-03
# 5                   3.78e-03
# 6                   2.44e-03
# 7                   3.24e-03
# 8                   1.89e-04
# 9                   2.37e-03
# 10                  3.04e-03
# 11                  4.16e-04
#
# [12 rows x 40 columns]

# %% [markdown]
# Now we compute the order of the schemes for given boundary condition and m and change the header to something nice

# %%
bc = "Dirichlet"
m = 1 
names = ["centered", "dss", "divCentered", "invCenteredLap"]
columns = []
for name in names :
    columns.append( bc+"."+name)
df_dir = df[["mx", "Nx", "Nz"]+columns]
df_dir = df_dir.loc [ df_dir["mx"]==m]
df_dir = df_dir.sort_values( by=['mx','Nx','Nz']) # sort
for name in names:
    df_dir.insert(df_dir.columns.get_loc(bc+"."+name)+1,column="order."+name, value=df_dir.loc[:,bc+"."+name])
    df_dir["order."+name] = (np.log ( df_dir["order."+name]/ df_dir["order."+name].shift(1))/
        np.log( df_dir["Nz"].shift(1)/df_dir["Nz"]))
df_dir.set_index(['mx','Nx','Nz'], inplace=True)
headers = ["$\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}}",
                                 "$\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}}",
                                 "$\nabla \cdot ( {\mathbf{\hat b}} f)$",
                                 "$\Delta_\parallel^{-1} f$"]
df_dir.columns=pd.MultiIndex.from_product([headers,["error", "order"] ])
df_dir
# Out:
#            $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}}           \
#                                                     error    order
# mx Nx  Nz
# 1  10  5                                         2.70e-01      nan
#    16  10                                        8.05e-02 1.75e+00
#    26  20                                        2.23e-02 1.85e+00
#    40  40                                        6.09e-03 1.87e+00
#    64  80                                        1.69e-03 1.85e+00
#    100 160                                       4.85e-04 1.80e+00
#
#            $\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}}           \
#                                                        error    order
# mx Nx  Nz
# 1  10  5                                            2.43e-01      nan
#    16  10                                           1.29e-01 9.11e-01
#    26  20                                           6.90e-02 9.06e-01
#    40  40                                           4.00e-02 7.84e-01
#    64  80                                           2.54e-02 6.56e-01
#    100 160                                          1.69e-02 5.90e-01
#
#            $\nabla \cdot ( {\mathbf{\hat b}} f)$            \
#                                            error     order
# mx Nx  Nz
# 1  10  5                                4.18e-01       nan
#    16  10                               6.88e-01 -7.17e-01
#    26  20                               1.40e+00 -1.03e+00
#    40  40                               3.02e+00 -1.11e+00
#    64  80                               6.35e+00 -1.07e+00
#    100 160                              1.22e+01 -9.42e-01
#
#            $\Delta_\parallel^{-1} f$
#                                error     order
# mx Nx  Nz
# 1  10  5                    5.08e-03       nan
#    16  10                   3.24e-03  6.51e-01
#    26  20                   4.04e-03 -3.21e-01
#    40  40                   3.78e-03  9.61e-02
#    64  80                   3.04e-03  3.13e-01
#    100 160                  2.37e-03  3.63e-01

# %% [markdown]
# We would like the order to be displayed differently.
# In pandas we must convert the columns to strings to do that.

# %%
#define conversion function 
def orderToString(x): 
    if np.isnan(x) : return 'n/a'
    return'%.2f'% x

def errorToString(x):
    return '%.2e' % x

# %%
string_df_dir = df_dir
for header in headers :  
    string_df_dir[header, "error"]=string_df_dir[header, "error"].apply( errorToString)
    string_df_dir[header, "order"]=string_df_dir[header, "order"].apply( orderToString)
string_df_dir
# Out:
#            $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}}        \
#                                                     error order
# mx Nx  Nz
# 1  10  5                                         2.70e-01   n/a
#    16  10                                        8.05e-02  1.75
#    26  20                                        2.23e-02  1.85
#    40  40                                        6.09e-03  1.87
#    64  80                                        1.69e-03  1.85
#    100 160                                       4.85e-04  1.80
#
#            $\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}}        \
#                                                        error order
# mx Nx  Nz
# 1  10  5                                            2.43e-01   n/a
#    16  10                                           1.29e-01  0.91
#    26  20                                           6.90e-02  0.91
#    40  40                                           4.00e-02  0.78
#    64  80                                           2.54e-02  0.66
#    100 160                                          1.69e-02  0.59
#
#            $\nabla \cdot ( {\mathbf{\hat b}} f)$         \
#                                            error  order
# mx Nx  Nz
# 1  10  5                                4.18e-01    n/a
#    16  10                               6.88e-01  -0.72
#    26  20                               1.40e+00  -1.03
#    40  40                               3.02e+00  -1.11
#    64  80                               6.35e+00  -1.07
#    100 160                              1.22e+01  -0.94
#
#            $\Delta_\parallel^{-1} f$
#                                error  order
# mx Nx  Nz
# 1  10  5                    5.08e-03    n/a
#    16  10                   3.24e-03   0.65
#    26  20                   4.04e-03  -0.32
#    40  40                   3.78e-03   0.10
#    64  80                   3.04e-03   0.31
#    100 160                  2.37e-03   0.36

# %%
filename='ds_cylindrical_dirichlet'+str(m)+'.tex'
with open(filename, 'wb') as f:
    f.write(bytes(df_dir.to_latex(
        escape=False,column_format='lllp{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}',
                               bold_rows=True),'UTF-8'))
