# %%
import json
import simplesimdb as database
import yaml
import numpy as np
import pandas as pd
from IPython.display import display, HTML # to display tables in for loop

pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
#define conversion function 
def orderToString(x): 
    if np.isnan(x) : return 'n/a'
    return'%.2f'% x

def errorToString(x):
    return '%.2e' % x

# %%
# db.delete_all()

# %%
# Create Database manger
db = database.Manager( directory = 'data_ds_guenter_t',
        filetype='yaml', executable='./execute_guenter.sh')

# %%
# First generate some data
support=[1,12]
methods=["dg", "linear", "linear-nearest", "linear-linear" ]
resolutionDG = [ (10,5), (16,10), (26,20), (40,40), (64,80) ]#, (100,160)]
resolutionL =  [ (8,5), (15,10), (30,20), (60,40), (120,80) ]#, (100,160)]
# create simulation database
for method in methods :
    for m in support :
        if m == 1  and method == "linear-nearest":
                continue
        if m == 1  and method == "linear-linear":
                continue
        if method == "dg" :
            for n in resolutionDG :
                inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                    "mx" : m, "my" : m, "method" : method }
                print( inputfile)
                db.create( inputfile, error="display")
        else :
            for n in resolutionL :
                inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                    "mx" : m, "my" : m, "method" : method }
                print( inputfile)
                db.create( inputfile, error="display")
# Out:
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation 912df4...29fd.yaml
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation 7772a5...52e4.yaml
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation f6abbf...b69d.yaml
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation 813722...5f99.yaml
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation 4a2eb4...524e.yaml
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 12, 'my': 12, 'method': 'dg'}
# Running simulation 215a8c...ba08.yaml
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 12, 'my': 12, 'method': 'dg'}
# Running simulation 5bbb06...79b5.yaml
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 12, 'my': 12, 'method': 'dg'}
# Running simulation b700f1...a319.yaml
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 12, 'my': 12, 'method': 'dg'}
# Running simulation aca915...7f35.yaml
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 12, 'my': 12, 'method': 'dg'}
# Running simulation 0f4f03...3523.yaml
# {'n': 3, 'Nx': 8, 'Ny': 8, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation a02eab...becc.yaml
# {'n': 3, 'Nx': 15, 'Ny': 15, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation 790007...4c9b.yaml
# {'n': 3, 'Nx': 30, 'Ny': 30, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation a54d1f...5b56.yaml
# {'n': 3, 'Nx': 60, 'Ny': 60, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation 1566a1...e547.yaml
# {'n': 3, 'Nx': 120, 'Ny': 120, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation d15b35...6ff1.yaml
# {'n': 3, 'Nx': 8, 'Ny': 8, 'Nz': 5, 'mx': 12, 'my': 12, 'method': 'linear'}
# Running simulation cc2870...43dd.yaml
# {'n': 3, 'Nx': 15, 'Ny': 15, 'Nz': 10, 'mx': 12, 'my': 12, 'method': 'linear'}
# Running simulation 5a085f...bda5.yaml
# {'n': 3, 'Nx': 30, 'Ny': 30, 'Nz': 20, 'mx': 12, 'my': 12, 'method': 'linear'}
# Running simulation 008ade...a1d4.yaml
# {'n': 3, 'Nx': 60, 'Ny': 60, 'Nz': 40, 'mx': 12, 'my': 12, 'method': 'linear'}
# Running simulation b1aaf0...08e2.yaml
# {'n': 3, 'Nx': 120, 'Ny': 120, 'Nz': 80, 'mx': 12, 'my': 12, 'method': 'linear'}
# Running simulation 36447b...7a94.yaml
# {'n': 3, 'Nx': 8, 'Ny': 8, 'Nz': 5, 'mx': 12, 'my': 12, 'method': 'linear-nearest'}
# Running simulation 700b65...c4dd.yaml
# {'n': 3, 'Nx': 15, 'Ny': 15, 'Nz': 10, 'mx': 12, 'my': 12, 'method': 'linear-nearest'}
# Running simulation 080002...6a4f.yaml
# {'n': 3, 'Nx': 30, 'Ny': 30, 'Nz': 20, 'mx': 12, 'my': 12, 'method': 'linear-nearest'}
# Running simulation b2d1d7...ec95.yaml
# {'n': 3, 'Nx': 60, 'Ny': 60, 'Nz': 40, 'mx': 12, 'my': 12, 'method': 'linear-nearest'}
# Running simulation abec06...471f.yaml
# {'n': 3, 'Nx': 120, 'Ny': 120, 'Nz': 80, 'mx': 12, 'my': 12, 'method': 'linear-nearest'}
# Running simulation a8f718...c207.yaml
# {'n': 3, 'Nx': 8, 'Ny': 8, 'Nz': 5, 'mx': 12, 'my': 12, 'method': 'linear-linear'}
# Running simulation 49c10b...d000.yaml
# {'n': 3, 'Nx': 15, 'Ny': 15, 'Nz': 10, 'mx': 12, 'my': 12, 'method': 'linear-linear'}
# Running simulation 314a5b...ba91.yaml
# {'n': 3, 'Nx': 30, 'Ny': 30, 'Nz': 20, 'mx': 12, 'my': 12, 'method': 'linear-linear'}
# Running simulation e54362...136b.yaml
# {'n': 3, 'Nx': 60, 'Ny': 60, 'Nz': 40, 'mx': 12, 'my': 12, 'method': 'linear-linear'}
# Running simulation ad4a77...60b9.yaml
# {'n': 3, 'Nx': 120, 'Ny': 120, 'Nz': 80, 'mx': 12, 'my': 12, 'method': 'linear-linear'}
# Running simulation f85b33...b2a1.yaml

# %%
content = db.table()
for entry in content:
    if entry["mx"] == 10 and entry["method"] == "linear":
        with open( db.outfile( entry) ) as f:
            output = yaml.full_load(f)
            print( output)

# %%
content = db.table()
df = pd.io.json.json_normalize(content)
df
# Out:
#      Nx   Ny  Nz          method  mx  my  n
# 0     8    8   5          linear   1   1  3
# 1    40   40  40              dg   1   1  3
# 2    10   10   5              dg  12  12  3
# 3    40   40  40              dg  12  12  3
# 4   120  120  80          linear  12  12  3
# 5    10   10   5              dg   1   1  3
# 6    30   30  20          linear  12  12  3
# 7    60   60  40  linear-nearest  12  12  3
# 8    26   26  20              dg   1   1  3
# 9    64   64  80              dg  12  12  3
# 10   60   60  40          linear  12  12  3
# 11   15   15  10  linear-nearest  12  12  3
# 12  120  120  80          linear   1   1  3
# 13   15   15  10          linear  12  12  3
# 14   26   26  20              dg  12  12  3
# 15   60   60  40          linear   1   1  3
# 16    8    8   5          linear  12  12  3
# 17   15   15  10   linear-linear  12  12  3
# 18   30   30  20          linear   1   1  3
# 19   16   16  10              dg  12  12  3
# 20   16   16  10              dg   1   1  3
# 21   60   60  40   linear-linear  12  12  3
# 22   64   64  80              dg   1   1  3
# 23   15   15  10          linear   1   1  3
# 24   30   30  20   linear-linear  12  12  3
# 25  120  120  80   linear-linear  12  12  3
# 26  120  120  80  linear-nearest  12  12  3
# 27   30   30  20  linear-nearest  12  12  3
# 28    8    8   5  linear-nearest  12  12  3
# 29    8    8   5   linear-linear  12  12  3

# %%
table=list()
for data in content :
    with open( db.outfile( data)) as f:
        output = yaml.full_load(f)
        table.append( output)
df = pd.io.json.json_normalize(table)
df
# Out:
#     n   Nx   Ny  Nz  mx  my          method  Guenter.forward  \
# 0   3    8    8   5   1   1          linear         6.00e-01
# 1   3   40   40  40   1   1              dg         7.82e-02
# 2   3   10   10   5  12  12              dg         5.99e-01
# 3   3   40   40  40  12  12              dg         7.82e-02
# 4   3  120  120  80  12  12          linear         3.91e-02
# 5   3   10   10   5   1   1              dg         5.99e-01
# 6   3   30   30  20  12  12          linear         1.56e-01
# 7   3   60   60  40  12  12  linear-nearest         7.82e-02
# 8   3   26   26  20   1   1              dg         1.56e-01
# 9   3   64   64  80  12  12              dg         3.91e-02
# 10  3   60   60  40  12  12          linear         7.82e-02
# 11  3   15   15  10  12  12  linear-nearest         3.10e-01
# 12  3  120  120  80   1   1          linear         3.92e-02
# 13  3   15   15  10  12  12          linear         3.10e-01
# 14  3   26   26  20  12  12              dg         1.56e-01
# 15  3   60   60  40   1   1          linear         7.84e-02
# 16  3    8    8   5  12  12          linear         5.98e-01
# 17  3   15   15  10  12  12   linear-linear         3.10e-01
# 18  3   30   30  20   1   1          linear         1.56e-01
# 19  3   16   16  10  12  12              dg         3.10e-01
# 20  3   16   16  10   1   1              dg         3.10e-01
# 21  3   60   60  40  12  12   linear-linear         7.82e-02
# 22  3   64   64  80   1   1              dg         3.91e-02
# 23  3   15   15  10   1   1          linear         3.10e-01
# 24  3   30   30  20  12  12   linear-linear         1.56e-01
# 25  3  120  120  80  12  12   linear-linear         3.91e-02
# 26  3  120  120  80  12  12  linear-nearest         3.91e-02
# 27  3   30   30  20  12  12  linear-nearest         1.56e-01
# 28  3    8    8   5  12  12  linear-nearest         5.98e-01
# 29  3    8    8   5  12  12   linear-linear         5.98e-01
#
#     Guenter.forward_vol  Guenter.backward  ...  Guenter.centeredST_vol  \
# 0             -9.76e-04          6.00e-01  ...               -2.39e-03
# 1             -2.78e-04          7.82e-02  ...               -4.02e-05
# 2             -2.64e-03          5.99e-01  ...               -2.40e-03
# 3             -2.78e-04          7.82e-02  ...               -4.02e-05
# 4             -1.35e-04          3.91e-02  ...               -1.00e-05
# 5             -2.64e-03          5.99e-01  ...               -2.40e-03
# 26           1.88e-16           4.49e-14          3.61e-04
# 27           7.10e-13           1.58e-10          6.61e-04
# 28           8.20e-10           3.29e-08          2.81e-03
# 29           8.20e-10           3.29e-08          2.67e-03
#
# [30 rows x 45 columns]

# %%
names = ["centered", "divCentered", "directLap", "divCentered_vol", "directLap_vol"]#, "Tp_mass_err", "Tp_TV_err"]
columns = []
for name in names :
    columns.append( "Guenter."+name)
dflist = []
string_mlist = []
string_methodlist = []
string_dflist = []
for method in methods:
    for m in support:
        if m == 1  and method == "linear-nearest":
            continue
        if m == 1  and method == "linear-linear":
            continue
        df_dir = df[["method", "mx", "Nx", "Nz"]+columns].copy()
        df_dir = df_dir.loc [ df_dir["mx"]==m]
        df_dir = df_dir.loc[ df_dir["method"] == method]
        df_dir = df_dir.sort_values( by=['mx','Nx','Nz']) # sort
        for name in names:
            df_dir.insert(df_dir.columns.get_loc("Guenter."+name)+1,column="order."+name,
                          value=df_dir.loc[:,"Guenter."+name])
            df_dir["order."+name] = (np.log ( np.abs(df_dir["order."+name]/ df_dir["order."+name].shift(1)))/
                np.log( df_dir["Nz"].shift(1)/df_dir["Nz"]))
        df_dir.drop(['method','mx'],axis=1,inplace=True)
        df_dir.set_index(['Nx','Nz'], inplace=True)
        headers = [ "$\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}",
                    "$\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}",
                    "$\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}",
                    "$\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $",
                    "$\int dV \Delta_\parallel^{CC} f $",
                    #"$\int dV F^+$",
                    #"$\int dV |\nabla_\perp F^+|$"
                  ]
        df_dir.columns=pd.MultiIndex.from_product([headers,["error", "order"] ])
        dflist.append(df_dir)
        string_df_dir = df_dir.copy()
        for header in headers :  
            string_df_dir[header, "error"]=string_df_dir[header, "error"].apply( errorToString)
            string_df_dir[header, "order"]=string_df_dir[header, "order"].apply( orderToString)
        string_dflist.append(string_df_dir)
        string_methodlist.append( method)
        string_mlist.append(str(m))

# %%
for i in range(0,len(string_dflist)):
    display( string_dflist[i])
    print( "Method: ", string_methodlist[i])
    print( "mx:     ", string_mlist[i])
    filename='ds_guenter_'+string_methodlist[i]+string_mlist[i]+'.tex'
    with open(filename, 'wb') as f:
        f.write(bytes(string_dflist[i].to_latex(
            escape=False,
            #column_format='llp{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}'
            column_format='llllllllllll',
                                   bold_rows=True),'UTF-8'))
# Out:
#       $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                 error order
# Nx Nz
# 10 5                                         2.43e-01   n/a
# 16 10                                        6.46e-02  1.91
# 26 20                                        1.64e-02  1.98
# 40 40                                        4.11e-03  1.99
# 64 80                                        1.03e-03  2.00
#
#       $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                       error
# Nx Nz
# 10 5                                            2.46e-01
# 16 10                                           6.58e-02
# 26 20                                           1.67e-02
# 40 40                                           4.20e-03
# 64 80                                           1.05e-03
#
#             $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}        \
#       order                                          error order
# Nx Nz
# 10 5    n/a                                       1.22e-01   n/a
# 16 10  1.90                                       3.18e-02  1.94
# 26 20  1.98                                       8.05e-03  1.98
# 40 40  1.99                                       2.02e-03  1.99
# 64 80  2.00                                       5.15e-04  1.97
#
#       $\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $        \
#                                                     error order
# Nx Nz
# 10 5                                            7.54e-08    n/a
# 16 10                                          -4.24e-10   7.47
# 26 20                                           2.35e-12   7.49
# 40 40                                           3.20e-13   2.88
# 64 80                                           5.06e-15   5.98
#
#       $\int dV \Delta_\parallel^{CC} f $
#                                    error order
# Nx Nz
# 10 5                            4.95e-08   n/a
# 16 10                          -1.62e-09  4.94
# 26 20                          -9.67e-10  0.74
# 40 40                          -7.29e-11  3.73
# 64 80                          -4.52e-12  4.01
# Method:  dg
# mx:      1
#       $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                 error order
# Nx Nz
# 10 5                                         2.43e-01   n/a
# 16 10                                        6.46e-02  1.91
# 26 20                                        1.64e-02  1.98
# 40 40                                        4.11e-03  1.99
# 64 80                                        1.03e-03  2.00
#
#       $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                       error
# Nx Nz
# 10 5                                            2.46e-01
# 16 10                                           6.58e-02
# 26 20                                           1.67e-02
# 40 40                                           4.20e-03
# 64 80                                           1.05e-03
#
#             $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}        \
#       order                                          error order
# Nx Nz
# 10 5    n/a                                       1.22e-01   n/a
# 16 10  1.90                                       3.18e-02  1.94
# 26 20  1.98                                       8.05e-03  1.98
# 40 40  1.99                                       2.02e-03  2.00
# 64 80  2.00                                       5.08e-04  1.99
#
#       $\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $        \
#                                                     error order
# Nx Nz
# 10 5                                            7.41e-08    n/a
# 16 10                                          -4.28e-10   7.44
# 26 20                                           2.34e-12   7.51
# 40 40                                           3.20e-13   2.87
# 64 80                                           5.07e-15   5.98
#
#       $\int dV \Delta_\parallel^{CC} f $
#                                    error order
# Nx Nz
# 10 5                            5.06e-08   n/a
# 16 10                          -1.59e-09  4.99
# 26 20                          -9.66e-10  0.72
# 40 40                          -7.28e-11  3.73
# 64 80                          -4.55e-12  4.00
# Method:  dg
# mx:      12
#        $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                  error order
# Nx  Nz
# 8   5                                         2.46e-01   n/a
# 15  10                                        6.59e-02  1.90
# 30  20                                        1.68e-02  1.97
# 60  40                                        4.27e-03  1.98
# 120 80                                        1.09e-03  1.97
#
#        $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                        error
# Nx  Nz
# 8   5                                            2.49e-01
# 15  10                                           6.71e-02
# 30  20                                           1.72e-02
# 60  40                                           4.36e-03
# 120 80                                           1.11e-03
#
#              $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}         \
#        order                                          error  order
# Nx  Nz
# 8   5    n/a                                       1.25e-01    n/a
# 15  10  1.90                                       3.29e-02   1.93
# 30  20  1.97                                       7.89e-03   2.06
# 60  40  1.98                                       2.48e-03   1.67
# 120 80  1.97                                       2.55e-03  -0.04
#
#        $\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $         \
#                                                      error  order
# Nx  Nz
# 8   5                                           -5.85e-06     n/a
# 15  10                                          -7.60e-06   -0.38
# 30  20                                           2.18e-07    5.12
# 60  40                                           1.46e-08    3.90
# 120 80                                           9.41e-10    3.96
#
#        $\int dV \Delta_\parallel^{CC} f $
#                                     error order
# Nx  Nz
# 8   5                            9.34e-04   n/a
# 15  10                           8.57e-04  0.12
# 30  20                           6.88e-04  0.32
# 60  40                           6.16e-04  0.16
# 120 80                           5.98e-04  0.04
# Method:  linear
# mx:      1
#        $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                  error order
# Nx  Nz
# 8   5                                         2.46e-01   n/a
# 15  10                                        6.59e-02  1.90
# 30  20                                        1.68e-02  1.97
# 60  40                                        4.26e-03  1.98
# 120 80                                        1.08e-03  1.97
#
#        $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                        error
# Nx  Nz
# 8   5                                            2.50e-01
# 15  10                                           6.71e-02
# 30  20                                           1.71e-02
# 60  40                                           4.34e-03
# 120 80                                           1.10e-03
#
#              $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}        \
#        order                                          error order
# Nx  Nz
# 8   5    n/a                                       1.27e-01   n/a
# 15  10  1.90                                       3.42e-02  1.89
# 30  20  1.97                                       9.05e-03  1.92
# 60  40  1.98                                       2.47e-03  1.87
# 120 80  1.98                                       7.28e-04  1.76
#
#        $\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $         \
#                                                      error  order
# Nx  Nz
# 8   5                                            6.65e-06     n/a
# 15  10                                           5.73e-08    6.86
# 30  20                                           1.02e-07   -0.84
# 60  40                                          -7.56e-09    3.76
# 120 80                                           4.81e-10    3.98
#
#        $\int dV \Delta_\parallel^{CC} f $
#                                     error  order
# Nx  Nz
# 8   5                           -9.22e-06    n/a
# 15  10                           9.32e-07   3.31
# 30  20                          -1.03e-06  -0.15
# 60  40                           3.84e-07   1.43
# 120 80                           1.56e-06  -2.02
# Method:  linear
# mx:      12
#        $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                  error order
# Nx  Nz
# 8   5                                         2.46e-01   n/a
# 15  10                                        6.58e-02  1.90
# 30  20                                        1.68e-02  1.97
# 60  40                                        4.24e-03  1.99
# 120 80                                        1.07e-03  1.98
#
#        $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                        error
# Nx  Nz
# 8   5                                            2.49e-01
# 15  10                                           6.70e-02
# 30  20                                           1.71e-02
# 60  40                                           4.32e-03
# 120 80                                           1.09e-03
#
#              $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}        \
#        order                                          error order
# Nx  Nz
# 8   5    n/a                                       1.26e-01   n/a
# 15  10  1.90                                       3.38e-02  1.90
# 30  20  1.97                                       8.85e-03  1.93
# 60  40  1.99                                       2.37e-03  1.90
# 120 80  1.98                                       6.60e-04  1.84
#
#        $\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $         \
#                                                      error  order
# Nx  Nz
# 8   5                                            6.52e-06     n/a
# 15  10                                           4.22e-08    7.27
# 30  20                                           1.02e-07   -1.27
# 60  40                                          -7.59e-09    3.75
# 120 80                                           4.80e-10    3.98
#
#        $\int dV \Delta_\parallel^{CC} f $
#                                     error  order
# Nx  Nz
# 8   5                           -9.41e-06    n/a
# 15  10                           9.36e-07   3.33
# 30  20                          -1.04e-06  -0.15
# 60  40                           3.85e-07   1.43
# 120 80                           1.56e-06  -2.02
# Method:  linear-nearest
# mx:      12
#        $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                  error order
# Nx  Nz
# 8   5                                         2.47e-01   n/a
# 15  10                                        6.62e-02  1.90
# 30  20                                        1.69e-02  1.97
# 60  40                                        4.28e-03  1.98
# 120 80                                        1.09e-03  1.97
#
#        $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                        error
# Nx  Nz
# 8   5                                            2.50e-01
# 15  10                                           6.74e-02
# 30  20                                           1.72e-02
# 60  40                                           4.37e-03
# 120 80                                           1.11e-03
#
#              $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}        \
#        order                                          error order
# Nx  Nz
# 8   5    n/a                                       1.28e-01   n/a
# 15  10  1.89                                       3.45e-02  1.89
# 30  20  1.97                                       9.08e-03  1.92
# 60  40  1.98                                       2.46e-03  1.88
# 120 80  1.98                                       6.97e-04  1.82
#
#        $\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $         \
#                                                      error  order
# Nx  Nz
# 8   5                                            6.00e-06     n/a
# 15  10                                          -1.27e-08    8.88
# 30  20                                           9.69e-08   -2.93
# 60  40                                          -7.97e-09    3.60
# 120 80                                           4.54e-10    4.13
#
#        $\int dV \Delta_\parallel^{CC} f $
#                                     error  order
# Nx  Nz
# 8   5                           -9.77e-06    n/a
# 15  10                           7.29e-07   3.74
# 30  20                          -1.08e-06  -0.57
# 60  40                           3.74e-07   1.53
# 120 80                           1.56e-06  -2.06
# Method:  linear-linear
# mx:      12

# %% [markdown]
# Q: Why is volume $F^+$ not exactly (or at least better) conserved on the refined grids?
# A: Because we do not integrate the volume form on the fine grid, and assume we can drag it out of the projection integral
