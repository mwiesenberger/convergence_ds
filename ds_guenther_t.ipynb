# %%
import json
import simplesimdb as database
import yaml
import numpy as np
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
#define conversion function 
def orderToString(x): 
    if np.isnan(x) : return 'n/a'
    return'%.2f'% x

def errorToString(x):
    return '%.2e' % x

# %%
# Create Database manger
db = database.Manager( directory = 'data_ds_guenther_t',
        filetype='yaml', executable='./execute_guenther.sh')
# db.delete_all()

# %%
# First generate some data
support=[1,10]
methods=["dg","linear", "cubic"]
resolutionDG = [ (10,5), (16,10), (26,20), (40,40), (64,80) ]#, (100,160)]
resolutionL =  [ (10,5), (20,10), (40,20), (80,40), (160,80) ]#, (100,160)]
# create simulation database
for method in methods :
    for m in support :
        for n in resolutionDG :
            inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                "mx" : m, "my" : m, "method" : method }
            print( inputfile)
            db.create( inputfile, error="display")
# Out:
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'cubic'}

# %%
content = db.table()
for entry in content:
    if entry["mx"] == 10 and entry["method"] == "linear":
        with open( db.outfile( entry) ) as f:
            output = yaml.full_load(f)
            print( output)
# Out:
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.165544, 'forward_vol': 7.21218e-05, 'backward': 0.165555, 'backward_vol': -9.7812e-05, 'forward2': 0.0406608, 'forward2_vol': 0.000196265, 'backward2': 0.0407005, 'backward2_vol': -0.000147204, 'centered': 0.0204901, 'centered_vol': -1.28451e-05, 'dss': 0.0252284, 'dss_vol': 9.43854e-05, 'centered_bc_along': 0.0204901, 'centered_bc_along_vol': -1.28451e-05, 'dss_bc_along': 0.0252284, 'dss_bc_along_vol': 9.43854e-05, 'divForward': 0.165807, 'divForward_vol': 0.000167659, 'divBackward': 0.165833, 'divBackward_vol': -0.000167656, 'divCentered': 0.0207008, 'divCentered_vol': 1.53022e-09, 'directLap': 0.0251935, 'directLap_vol': 0.000105922, 'invCenteredLap': 0.00024321, 'invCenteredLap_vol': 3.44319, 'Tp_mass_err': 0.000151709, 'Tp_l2_err': -0.000292364, 'Tp_TV_err': -0.00696979, 'centeredST': 0.0208225, 'centeredST_vol': -3.65445e-05, 'directLapST': 0.0252628, 'directLapST_vol': 0.000105896}, 'volume_error': {'minus': 1.14964e-12, 'plus': 1.14964e-12, 'grid': 1.31152e-09, 'Inv': 0.0999119}}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.0420576, 'forward_vol': 8.87741e-05, 'backward': 0.0420605, 'backward_vol': -9.03915e-05, 'forward2': 0.0049806, 'forward2_vol': 0.000128732, 'backward2': 0.005036, 'backward2_vol': -0.000125509, 'centered': 0.00138766, 'centered_vol': -8.08696e-07, 'dss': 0.094666, 'dss_vol': 0.000267774, 'centered_bc_along': 0.00138766, 'centered_bc_along_vol': -8.08696e-07, 'dss_bc_along': 0.094666, 'dss_bc_along_vol': 0.000267774, 'divForward': 0.0421239, 'divForward_vol': 0.000110865, 'divBackward': 0.0421278, 'divBackward_vol': -0.000110865, 'divCentered': 0.00140041, 'divCentered_vol': -1.51473e-10, 'directLap': 0.0947078, 'directLap_vol': 0.000280039, 'invCenteredLap': 0.000738628, 'invCenteredLap_vol': 3.44324, 'Tp_mass_err': 2.50858e-05, 'Tp_l2_err': -4.83932e-05, 'Tp_TV_err': -0.00270309, 'centeredST': 0.00148429, 'centeredST_vol': -2.31139e-06, 'directLapST': 0.0947059, 'directLapST_vol': 0.000280034}, 'volume_error': {'minus': 2.26173e-16, 'plus': 2.26173e-16, 'grid': 7.62202e-14, 'Inv': 0.101738}}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.624227, 'forward_vol': -0.000123218, 'backward': 0.624309, 'backward_vol': -0.000238317, 'forward2': 0.525456, 'forward2_vol': -0.000215722, 'backward2': 0.525738, 'backward2_vol': 0.000392681, 'centered': 0.278144, 'centered_vol': -0.000180768, 'dss': 0.192116, 'dss_vol': 3.91798e-05, 'centered_bc_along': 0.278144, 'centered_bc_along_vol': -0.000180768, 'dss_bc_along': 0.192116, 'dss_bc_along_vol': 3.91798e-05, 'divForward': 0.624987, 'divForward_vol': 0.00026461, 'divBackward': 0.625223, 'divBackward_vol': -0.000262114, 'divCentered': 0.279737, 'divCentered_vol': 1.24809e-06, 'directLap': 0.190888, 'directLap_vol': 4.16596e-05, 'invCenteredLap': 0.00194186, 'invCenteredLap_vol': 3.44313, 'Tp_mass_err': 0.000960083, 'Tp_l2_err': -0.00197629, 'Tp_TV_err': -0.02576, 'centeredST': 0.279572, 'centeredST_vol': -0.000486298, 'directLapST': 0.192057, 'directLapST_vol': 4.14853e-05}, 'volume_error': {'minus': 2.87579e-10, 'plus': 2.87579e-10, 'grid': 5.02309e-09, 'Inv': 0.0975792}}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.0833825, 'forward_vol': 9.62744e-05, 'backward': 0.0833874, 'backward_vol': -0.000102733, 'forward2': 0.0111804, 'forward2_vol': 0.000166318, 'backward2': 0.0112381, 'backward2_vol': -0.000153548, 'centered': 0.00526868, 'centered_vol': -3.22907e-06, 'dss': 0.0475219, 'dss_vol': 0.00016697, 'centered_bc_along': 0.00526868, 'centered_bc_along_vol': -3.22907e-06, 'dss_bc_along': 0.0475219, 'dss_bc_along_vol': 0.00016697, 'divForward': 0.083516, 'divForward_vol': 0.000141822, 'divBackward': 0.083525, 'divBackward_vol': -0.000141821, 'divCentered': 0.00532227, 'divCentered_vol': 1.87204e-10, 'directLap': 0.0475469, 'directLap_vol': 0.000179089, 'invCenteredLap': 0.00042821, 'invCenteredLap_vol': 3.44323, 'Tp_mass_err': 6.41939e-05, 'Tp_l2_err': -0.000123688, 'Tp_TV_err': -0.00437882, 'centeredST': 0.00544691, 'centeredST_vol': -9.21956e-06, 'directLapST': 0.0475436, 'directLapST_vol': 0.000179079}, 'volume_error': {'minus': 1.85462e-14, 'plus': 1.85462e-14, 'grid': 5.528e-12, 'Inv': 0.102126}}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.326661, 'forward_vol': 2.15701e-05, 'backward': 0.326692, 'backward_vol': -0.000121917, 'forward2': 0.153742, 'forward2_vol': 0.000203444, 'backward2': 0.153786, 'backward2_vol': -4.06974e-05, 'centered': 0.0785639, 'centered_vol': -5.01736e-05, 'dss': 0.0573295, 'dss_vol': 6.08762e-05, 'centered_bc_along': 0.0785639, 'centered_bc_along_vol': -5.01736e-05, 'dss_bc_along': 0.0573295, 'dss_bc_along_vol': 6.08762e-05, 'divForward': 0.327147, 'divForward_vol': 0.000222419, 'divBackward': 0.327236, 'divBackward_vol': -0.000222366, 'divCentered': 0.0792933, 'divCentered_vol': 2.65713e-08, 'directLap': 0.0569476, 'directLap_vol': 7.0219e-05, 'invCenteredLap': 0.00056533, 'invCenteredLap_vol': 3.44316, 'Tp_mass_err': 0.000403032, 'Tp_l2_err': -0.000767298, 'Tp_TV_err': -0.0128372, 'centeredST': 0.0792896, 'centeredST_vol': -0.000140967, 'directLapST': 0.0574269, 'directLapST_vol': 7.01512e-05}, 'volume_error': {'minus': 2.34938e-11, 'plus': 2.34938e-11, 'grid': 4.72568e-09, 'Inv': 0.0988754}}

# %%
content = db.table()
df = pd.json_normalize(content)
df
# Out:
#     Nx  Ny  Nz  method  mx  my  n
# 0   64  64  80  linear   1   1  3
# 1   40  40  40      dg  10  10  3
# 2   16  16  10      dg  10  10  3
# 3   10  10   5      dg  10  10  3
# 4   10  10   5      dg   1   1  3
# 5   10  10   5   cubic  10  10  3
# 6   10  10   5   cubic   1   1  3
# 7   16  16  10   cubic  10  10  3
# 8   40  40  40   cubic   1   1  3
# 9   26  26  20      dg  10  10  3
# 10  64  64  80   cubic   1   1  3
# 11  64  64  80      dg   1   1  3
# 12  26  26  20  linear  10  10  3
# 13  10  10   5  linear   1   1  3
# 14  64  64  80  linear  10  10  3
# 15  40  40  40  linear   1   1  3
# 16  26  26  20   cubic  10  10  3
# 17  16  16  10  linear   1   1  3
# 18  10  10   5  linear  10  10  3
# 19  26  26  20   cubic   1   1  3
# 20  26  26  20      dg   1   1  3
# 21  40  40  40   cubic  10  10  3
# 22  64  64  80      dg  10  10  3
# 23  40  40  40  linear  10  10  3
# 24  16  16  10  linear  10  10  3
# 25  40  40  40      dg   1   1  3
# 26  16  16  10      dg   1   1  3
# 27  64  64  80   cubic  10  10  3
# 28  16  16  10   cubic   1   1  3
# 29  26  26  20  linear   1   1  3

# %%
table=list()
for data in content :
    with open( db.outfile( data)) as f:
        output = yaml.full_load(f)
        table.append( output)
df = pd.json_normalize(table)
df
# Out:
#     n  Nx  Ny  Nz  mx  my  method  Guenther.forward  Guenther.forward_vol  \
# 0   3  64  64  80   1   1  linear          4.19e-02              2.28e-04
# 1   3  40  40  40  10  10      dg          8.26e-02             -4.55e-05
# 2   3  16  16  10  10  10      dg          3.26e-01             -2.01e-04
# 3   3  10  10   5  10  10      dg          6.23e-01             -3.87e-04
# 4   3  10  10   5   1   1      dg          6.23e-01             -3.87e-04
# 5   3  10  10   5  10  10   cubic          6.23e-01             -3.87e-04
# 6   3  10  10   5   1   1   cubic          6.23e-01             -3.87e-04
# 7   3  16  16  10  10  10   cubic          3.26e-01             -2.01e-04
# 8   3  40  40  40   1   1   cubic          8.26e-02             -4.55e-05
# 9   3  26  26  20  10  10      dg          1.65e-01             -9.55e-05
# 10  3  64  64  80   1   1   cubic          4.13e-02             -2.21e-05
# 11  3  64  64  80   1   1      dg          4.13e-02             -2.21e-05
# 12  3  26  26  20  10  10  linear          1.66e-01              7.21e-05
# 13  3  10  10   5   1   1  linear          6.24e-01             -9.37e-06
# 14  3  64  64  80  10  10  linear          4.21e-02              8.88e-05
# 15  3  40  40  40   1   1  linear          8.33e-02              2.48e-04
# 16  3  26  26  20  10  10   cubic          1.65e-01             -9.55e-05
# 17  3  16  16  10   1   1  linear          3.27e-01              1.31e-04
# 18  3  10  10   5  10  10  linear          6.24e-01             -1.23e-04
# 19  3  26  26  20   1   1   cubic          1.65e-01             -9.55e-05
# 20  3  26  26  20   1   1      dg          1.65e-01             -9.55e-05
# 21  3  40  40  40  10  10   cubic          8.26e-02             -4.55e-05
# 22  3  64  64  80  10  10      dg          4.13e-02             -2.21e-05
# 23  3  40  40  40  10  10  linear          8.34e-02              9.63e-05
# 24  3  16  16  10  10  10  linear          3.27e-01              2.16e-05
# 25  3  40  40  40   1   1      dg          8.26e-02             -4.55e-05
# 26  3  16  16  10   1   1      dg          3.26e-01             -2.01e-04
# 27  3  64  64  80  10  10   cubic          4.13e-02             -2.21e-05
# 28  3  16  16  10   1   1   cubic          3.26e-01             -2.01e-04
# 29  3  26  26  20   1   1  linear          1.65e-01              2.10e-04
#
#     Guenther.backward  ...  Guenther.Tp_l2_err  Guenther.Tp_TV_err  \
# 0            4.19e-02  ...           -4.20e-05           -2.38e-04
# 1            8.26e-02  ...            1.33e-10            2.73e-05
# 2            3.26e-01  ...           -1.11e-08            1.54e-04
# 3            6.23e-01  ...            3.85e-06            7.27e-04
# 4            6.23e-01  ...            6.11e-06            6.94e-04
# 5            6.23e-01  ...            3.49e-07            5.58e-04
# 6            6.23e-01  ...            3.74e-07            5.37e-04
# 7            3.26e-01  ...           -5.36e-07            1.27e-04
# 8            8.26e-02  ...           -1.38e-08            2.67e-05
# 9            1.65e-01  ...            1.92e-09            6.55e-05
# 10           4.13e-02  ...           -2.11e-09            1.19e-05
# 11           4.13e-02  ...           -5.84e-10            1.19e-05
# 12           1.66e-01  ...           -2.92e-04           -6.97e-03
# 13           6.24e-01  ...           -1.60e-03           -2.09e-02
# 14           4.21e-02  ...           -4.84e-05           -2.70e-03
# 15           8.33e-02  ...           -1.09e-04           -7.64e-04
# 16           1.65e-01  ...           -7.64e-08            6.21e-05
# 17           3.27e-01  ...           -7.04e-04           -8.07e-03
# 18           6.24e-01  ...           -1.98e-03           -2.58e-02
# 19           1.65e-01  ...           -7.63e-08            6.21e-05
# 20           1.65e-01  ...            9.52e-08            6.38e-05
# 21           8.26e-02  ...           -1.38e-08            2.67e-05
# 22           4.13e-02  ...            9.87e-12            1.20e-05
# 23           8.34e-02  ...           -1.24e-04           -4.38e-03
# 24           3.27e-01  ...           -7.67e-04           -1.28e-02
# 25           8.26e-02  ...           -4.56e-09            2.69e-05
# 26           3.26e-01  ...           -6.80e-07            1.46e-04
# 27           4.13e-02  ...           -2.11e-09            1.19e-05
# 28           3.26e-01  ...           -5.39e-07            1.27e-04
# 29           1.66e-01  ...           -2.59e-04           -2.38e-03
#
#     Guenther.centeredST  Guenther.centeredST_vol  Guenther.directLapST  \
# 0              1.42e-03                -2.20e-06              1.81e-02
# 1              5.10e-03                -9.22e-06              3.93e-03
# 2              7.79e-02                -1.41e-04              5.81e-02
# 3              2.77e-01                -4.88e-04              1.92e-01
# 4              2.77e-01                -4.85e-04              1.92e-01
# 5              2.77e-01                -4.88e-04              1.92e-01
# 6              2.77e-01                -4.88e-04              1.92e-01
# 7              7.79e-02                -1.41e-04              5.80e-02
# 8              5.10e-03                -9.22e-06              3.93e-03
# 9              2.02e-02                -3.66e-05              1.54e-02
# 10             1.28e-03                -2.31e-06              9.86e-04
# 11             1.28e-03                -2.31e-06              9.91e-04
# 12             2.08e-02                -3.65e-05              2.53e-02
# 13             2.80e-01                -4.93e-04              1.92e-01
# 14             1.48e-03                -2.31e-06              9.47e-02
# 15             5.37e-03                -8.87e-06              1.26e-02
# 16             2.02e-02                -3.66e-05              1.54e-02
# 17             7.92e-02                -1.38e-04              5.70e-02
# 18             2.80e-01                -4.86e-04              1.92e-01
# 19             2.02e-02                -3.66e-05              1.54e-02
# 20             2.02e-02                -3.66e-05              1.54e-02
# 21             5.10e-03                -9.22e-06              3.93e-03
# 22             1.28e-03                -2.31e-06              9.88e-04
# 23             5.45e-03                -9.22e-06              4.75e-02
# 24             7.93e-02                -1.41e-04              5.74e-02
# 25             5.10e-03                -9.23e-06              3.93e-03
# 26             7.79e-02                -1.41e-04              5.80e-02
# 27             1.28e-03                -2.31e-06              9.86e-04
# 28             7.79e-02                -1.41e-04              5.80e-02
# 29             2.07e-02                -3.67e-05              1.58e-02
#
#     Guenther.directLapST_vol  volume_error.minus  volume_error.plus  \
# 0                   6.37e-04            2.26e-16           2.26e-16
# 1                  -1.89e-10            1.85e-14           1.85e-14
# 2                  -1.22e-09            2.35e-11           2.35e-11
# 3                   5.93e-08            2.88e-10           2.88e-10
# 4                   5.93e-08            2.88e-10           2.88e-10
# 5                   5.93e-08            2.88e-10           2.88e-10
# 6                   5.93e-08            2.88e-10           2.88e-10
# 7                  -1.22e-09            2.35e-11           2.35e-11
# 8                  -1.89e-10            1.85e-14           1.85e-14
# 9                  -1.76e-09            1.15e-12           1.15e-12
# 10                 -1.18e-11            2.26e-16           2.26e-16
# 11                 -1.18e-11            2.26e-16           2.26e-16
# 12                  1.06e-04            1.15e-12           1.15e-12
# 13                  5.99e-05            2.88e-10           2.88e-10
# 14                  2.80e-04            2.26e-16           2.26e-16
# 15                  3.74e-04            1.85e-14           1.85e-14
# 16                 -1.76e-09            1.15e-12           1.15e-12
# 17                  1.06e-04            2.35e-11           2.35e-11
# 18                  4.15e-05            2.88e-10           2.88e-10
# 19                 -1.76e-09            1.15e-12           1.15e-12
# 20                 -1.76e-09            1.15e-12           1.15e-12
# 21                 -1.89e-10            1.85e-14           1.85e-14
# 22                 -1.18e-11            2.26e-16           2.26e-16
# 23                  1.79e-04            1.85e-14           1.85e-14
# 24                  7.02e-05            2.35e-11           2.35e-11
# 25                 -1.89e-10            1.85e-14           1.85e-14
# 26                 -1.22e-09            2.35e-11           2.35e-11
# 27                 -1.18e-11            2.26e-16           2.26e-16
# 28                 -1.22e-09            2.35e-11           2.35e-11
# 29                  1.94e-04            1.15e-12           1.15e-12
#
#     volume_error.grid  volume_error.Inv
# 0            7.62e-14          2.56e-01
# 1            5.53e-12          2.23e-02
# 2            4.73e-09          1.02e-02
# 3            5.02e-09          7.79e-03
# 4            5.02e-09          1.35e+00
# 5            5.02e-09          1.05e-01
# 6            5.02e-09          5.80e-01
# 7            4.73e-09          1.06e-01
# 8            5.53e-12          2.21e-01
# 9            1.31e-09          1.49e-02
# 10           7.62e-14          2.21e-01
# 11           7.62e-14          9.47e-01
# 12           1.31e-09          9.99e-02
# 13           5.02e-09          4.13e-01
# 14           7.62e-14          1.02e-01
# 15           5.53e-12          2.47e-01
# 16           1.31e-09          1.07e-01
# 17           4.73e-09          2.78e-01
# 18           5.02e-09          9.76e-02
# 19           1.31e-09          2.51e-01
# 20           1.31e-09          9.70e-01
# 21           5.53e-12          1.10e-01
# 22           7.62e-14          2.89e-02
# 23           5.53e-12          1.02e-01
# 24           4.73e-09          9.89e-02
# 25           5.53e-12          9.18e-01
# 26           4.73e-09          8.75e-01
# 27           7.62e-14          1.11e-01
# 28           4.73e-09          3.05e-01
# 29           1.31e-09          2.60e-01
#
# [30 rows x 44 columns]

# %%
m = 10
method = "linear"
names = ["centered", "directLap", "directLap_vol", "divCentered", "divCentered_vol", "invCenteredLap","Tp_TV_err"]
columns = []
for name in names :
    columns.append( "Guenther."+name)
dflist = []
string_dflist = []
for method in ["linear", "dg"]:
    for m in [1,10]:
        df_dir = df[["method", "mx", "Nx", "Nz"]+columns].copy()
        df_dir = df_dir.loc [ df_dir["mx"]==m]
        df_dir = df_dir.loc[ df_dir["method"] == method]
        df_dir = df_dir.sort_values( by=['mx','Nx','Nz']) # sort
        for name in names:
            df_dir.insert(df_dir.columns.get_loc("Guenther."+name)+1,column="order."+name,
                          value=df_dir.loc[:,"Guenther."+name])
            df_dir["order."+name] = (np.log ( np.abs(df_dir["order."+name]/ df_dir["order."+name].shift(1)))/
                np.log( df_dir["Nz"].shift(1)/df_dir["Nz"]))
        df_dir.set_index(['method','mx','Nx','Nz'], inplace=True)
        headers = [ "$\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}",
                    "$\Delta_\parallel$ Eq.~\eqref{eq:second_order}",
                    "$\int dV \Delta_\parallel f / ||f||_2$",
                    "$\nabla \cdot ( {\mathbf{\hat b}} f)$",
                    "$\int dV \nabla \cdot ( {\mathbf{\hat b}} f) / ||f||_2$",
                    "$(1-\Delta_\parallel)^{-1} f$",
                  "$|\nabla_\perp f|$"]
        df_dir.columns=pd.MultiIndex.from_product([headers,["error", "order"] ])
        dflist.append(df_dir)
        string_df_dir = df_dir.copy()
        for header in headers :  
            string_df_dir[header, "error"]=string_df_dir[header, "error"].apply( errorToString)
            string_df_dir[header, "order"]=string_df_dir[header, "order"].apply( orderToString)
        string_dflist.append(string_df_dir)

# %%
string_dflist[0]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# linear 1  10 5                                       2.78e-01   n/a
#           16 10                                      7.85e-02  1.82
#           26 20                                      2.05e-02  1.94
#           40 40                                      5.25e-03  1.96
#           64 80                                      1.38e-03  1.93
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}         \
#                                                          error  order
# method mx Nx Nz
# linear 1  10 5                                        1.91e-01    n/a
#           16 10                                       5.65e-02   1.76
#           26 20                                       1.57e-02   1.85
#           40 40                                       1.26e-02   0.32
#           64 80                                       1.81e-02  -0.52
#
#                 $\int dV \Delta_\parallel f / ||f||_2$         \
#                                                  error  order
# method mx Nx Nz
# linear 1  10 5                                6.01e-05    n/a
#           16 10                               1.06e-04  -0.82
#           26 20                               1.94e-04  -0.88
#           40 40                               3.74e-04  -0.95
#           64 80                               6.37e-04  -0.77
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# linear 1  10 5                               2.80e-01   n/a
#           16 10                              7.93e-02  1.82
#           26 20                              2.07e-02  1.94
#           40 40                              5.30e-03  1.96
#           64 80                              1.39e-03  1.93
#
#                 $\int dV \nabla \cdot ( {\mathbf{\hat b}} f) / ||f||_2$        \
#                                                                   error order
# method mx Nx Nz
# linear 1  10 5                                            8.91e-07        n/a
#           16 10                                          -1.50e-07       2.57
#           26 20                                          -5.08e-08       1.57
#           40 40                                          -1.34e-08       1.92
#           64 80                                          -2.97e-09       2.18
#
#                 $(1-\Delta_\parallel)^{-1} f$        $|\nabla_\perp f|$
#                                         error  order              error order
# method mx Nx Nz
# linear 1  10 5                       1.94e-03    n/a          -2.09e-02   n/a
#           16 10                      5.61e-04   1.79          -8.07e-03  1.37
#           26 20                      1.52e-04   1.88          -2.38e-03  1.76
#           40 40                      1.23e-04   0.31          -7.64e-04  1.64
#           64 80                      1.76e-04  -0.52          -2.38e-04  1.68

# %%
string_dflist[1]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# linear 10 10 5                                       2.78e-01   n/a
#           16 10                                      7.86e-02  1.82
#           26 20                                      2.05e-02  1.94
#           40 40                                      5.27e-03  1.96
#           64 80                                      1.39e-03  1.92
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}         \
#                                                          error  order
# method mx Nx Nz
# linear 10 10 5                                        1.91e-01    n/a
#           16 10                                       5.69e-02   1.75
#           26 20                                       2.52e-02   1.18
#           40 40                                       4.75e-02  -0.92
#           64 80                                       9.47e-02  -0.99
#
#                 $\int dV \Delta_\parallel f / ||f||_2$         \
#                                                  error  order
# method mx Nx Nz
# linear 10 10 5                                4.17e-05    n/a
#           16 10                               7.02e-05  -0.75
#           26 20                               1.06e-04  -0.59
#           40 40                               1.79e-04  -0.76
#           64 80                               2.80e-04  -0.64
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# linear 10 10 5                               2.80e-01   n/a
#           16 10                              7.93e-02  1.82
#           26 20                              2.07e-02  1.94
#           40 40                              5.32e-03  1.96
#           64 80                              1.40e-03  1.93
#
#                 $\int dV \nabla \cdot ( {\mathbf{\hat b}} f) / ||f||_2$        \
#                                                                   error order
# method mx Nx Nz
# linear 10 10 5                                            1.25e-06        n/a
#           16 10                                           2.66e-08       5.55
#           26 20                                           1.53e-09       4.12
#           40 40                                           1.87e-10       3.03
#           64 80                                          -1.51e-10       0.31
#
#                 $(1-\Delta_\parallel)^{-1} f$        $|\nabla_\perp f|$
#                                         error  order              error order
# method mx Nx Nz
# linear 10 10 5                       1.94e-03    n/a          -2.58e-02   n/a
#           16 10                      5.65e-04   1.78          -1.28e-02  1.00
#           26 20                      2.43e-04   1.22          -6.97e-03  0.88
#           40 40                      4.28e-04  -0.82          -4.38e-03  0.67
#           64 80                      7.39e-04  -0.79          -2.70e-03  0.70

# %%
string_dflist[2]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# dg     1  10 5                                       2.77e-01   n/a
#           16 10                                      7.79e-02  1.83
#           26 20                                      2.02e-02  1.95
#           40 40                                      5.10e-03  1.99
#           64 80                                      1.28e-03  2.00
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# dg     1  10 5                                        1.91e-01   n/a
#           16 10                                       5.76e-02  1.73
#           26 20                                       1.53e-02  1.91
#           40 40                                       3.89e-03  1.98
#           64 80                                       9.81e-04  1.99
#
#                 $\int dV \Delta_\parallel f / ||f||_2$         \
#                                                  error  order
# method mx Nx Nz
# dg     1  10 5                                6.23e-08    n/a
#           16 10                              -1.23e-09   5.66
#           26 20                              -1.76e-09  -0.52
#           40 40                              -1.88e-10   3.22
#           64 80                              -1.18e-11   4.00
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# dg     1  10 5                               2.78e-01   n/a
#           16 10                              7.87e-02  1.82
#           26 20                              2.04e-02  1.95
#           40 40                              5.16e-03  1.99
#           64 80                              1.29e-03  2.00
#
#                 $\int dV \nabla \cdot ( {\mathbf{\hat b}} f) / ||f||_2$  \
#                                                                   error
# method mx Nx Nz
# dg     1  10 5                                            2.36e-07
#           16 10                                          -2.64e-09
#           26 20                                          -4.87e-10
#           40 40                                           1.97e-13
#           64 80                                           7.97e-15
#
#                        $(1-\Delta_\parallel)^{-1} f$       $|\nabla_\perp f|$  \
#                  order                         error order              error
# method mx Nx Nz
# dg     1  10 5     n/a                      1.95e-03   n/a           6.94e-04
#           16 10   6.48                      5.72e-04  1.77           1.46e-04
#           26 20   2.44                      1.50e-04  1.93           6.38e-05
#           40 40  11.27                      3.79e-05  1.98           2.69e-05
#           64 80   4.63                      9.50e-06  2.00           1.19e-05
#
#
#                 order
# method mx Nx Nz
# dg     1  10 5    n/a
#           16 10  2.25
#           26 20  1.20
#           40 40  1.25
#           64 80  1.17

# %%
string_dflist[3]
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# dg     10 10 5                                       2.77e-01   n/a
#           16 10                                      7.79e-02  1.83
#           26 20                                      2.02e-02  1.95
#           40 40                                      5.10e-03  1.99
#           64 80                                      1.28e-03  2.00
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# dg     10 10 5                                        1.91e-01   n/a
#           16 10                                       5.76e-02  1.73
#           26 20                                       1.53e-02  1.91
#           40 40                                       3.89e-03  1.98
#           64 80                                       9.78e-04  1.99
#
#                 $\int dV \Delta_\parallel f / ||f||_2$         \
#                                                  error  order
# method mx Nx Nz
# dg     10 10 5                                6.26e-08    n/a
#           16 10                              -1.23e-09   5.67
#           26 20                              -1.76e-09  -0.52
#           40 40                              -1.88e-10   3.22
#           64 80                              -1.18e-11   4.00
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# dg     10 10 5                               2.78e-01   n/a
#           16 10                              7.87e-02  1.82
#           26 20                              2.04e-02  1.95
#           40 40                              5.16e-03  1.99
#           64 80                              1.29e-03  2.00
#
#                 $\int dV \nabla \cdot ( {\mathbf{\hat b}} f) / ||f||_2$  \
#                                                                   error
# method mx Nx Nz
# dg     10 10 5                                            2.34e-07
#           16 10                                          -2.65e-09
#           26 20                                          -4.87e-10
#           40 40                                           1.96e-13
#           64 80                                           7.90e-15
#
#                        $(1-\Delta_\parallel)^{-1} f$       $|\nabla_\perp f|$  \
#                  order                         error order              error
# method mx Nx Nz
# dg     10 10 5     n/a                      1.95e-03   n/a           7.27e-04
#           16 10   6.47                      5.72e-04  1.77           1.54e-04
#           26 20   2.44                      1.50e-04  1.93           6.55e-05
#           40 40  11.28                      3.79e-05  1.98           2.73e-05
#           64 80   4.64                      9.49e-06  2.00           1.20e-05
#
#
#                 order
# method mx Nx Nz
# dg     10 10 5    n/a
#           16 10  2.24
#           26 20  1.23
#           40 40  1.26
#           64 80  1.18

# %%
# filename='ds_guenther'+str(m)+'.tex'
# with open(filename, 'wb') as f:
#     f.write(bytes(df_dir.to_latex(
#         escape=False,column_format='llllp{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}',
#                                bold_rows=True),'UTF-8'))
