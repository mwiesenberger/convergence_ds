# %%
import json
import simplesimdb as database
import yaml
import numpy as np
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
# Create Database manger
db = database.Manager( directory = 'data_ds_guenther_t',
        filetype='yaml', executable='./execute_guenther.sh')
# db.delete_all()

# %%
# First generate some data
support=[1,10]
methods=["dg","linear", "cubic"]
resolutionDG = [ (10,5), (16,10), (26,20), (40,40), (64,80) ]#, (100,160)]
resolutionL =  [ (10,5), (20,10), (40,20), (80,40), (160,80) ]#, (100,160)]
# create simulation database
for method in methods :
    for m in support :
        if ( method == "linear"):
            for n in resolutionL :
                inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                    "mx" : m, "my" : m, "method" : method }
                print( inputfile)
                db.create( inputfile)  
        else :
            for n in resolutionDG :
                inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                    "mx" : m, "my" : m, "method" : method }
                print( inputfile)
#                 db.delete( inputfile)
                db.create( inputfile, error="display")
# Out:
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 20, 'Ny': 20, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 80, 'Ny': 80, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation ...446540c.yaml
# {'n': 3, 'Nx': 160, 'Ny': 160, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 20, 'Ny': 20, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 80, 'Ny': 80, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'linear'}
# Running simulation ...8540557.yaml
# {'n': 3, 'Nx': 160, 'Ny': 160, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'cubic'}

# %%
content = db.table()
for entry in content:
    if entry["mx"] == 10 and entry["method"] == "linear":
        with open( db.outfile( entry) ) as f:
            output = yaml.full_load(f)
            print( output)
# Out:
# {'n': 3, 'Nx': 160, 'Ny': 160, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.0417235, 'backward': 0.0417299, 'forward2': 0.00749432, 'backward2': 0.0075999, 'centered': 0.00146902, 'dss': 0.113866, 'centered_bc_along': 0.00146902, 'dss_bc_along': 0.113866, 'divForward': 2.12955, 'divBackward': 2.12879, 'divCentered': 0.164246, 'divDirectForward': 0.0416979, 'divDirectBackward': 0.0417043, 'divDirectCentered': 0.00146745, 'forwardLap': 0.0968701, 'backwardLap': 0.0968701, 'centeredLap': 0.16351, 'directLap': 0.113913, 'directLap_bc_along': 0.113913, 'invForwardLap': 0.000417384, 'invBackwardLap': 0.000417384, 'invCenteredLap': 0.00137726, 'directLapST': 0.113914}}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.624827, 'backward': 0.62502, 'forward2': 0.527596, 'backward2': 0.527883, 'centered': 0.278753, 'dss': 0.193926, 'centered_bc_along': 0.278753, 'dss_bc_along': 0.193926, 'divForward': 0.64169, 'divBackward': 0.641818, 'divCentered': 0.306052, 'divDirectForward': 0.624444, 'divDirectBackward': 0.624637, 'divDirectCentered': 0.2786, 'forwardLap': 0.226151, 'backwardLap': 0.226151, 'centeredLap': 0.528667, 'directLap': 0.194614, 'directLap_bc_along': 0.194614, 'invForwardLap': 0.00208755, 'invBackwardLap': 0.00208755, 'invCenteredLap': 0.00534092, 'directLapST': 0.194463}}
# {'n': 3, 'Nx': 20, 'Ny': 20, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.326737, 'backward': 0.326781, 'forward2': 0.155563, 'backward2': 0.155707, 'centered': 0.0789171, 'dss': 0.0658176, 'centered_bc_along': 0.0789171, 'dss_bc_along': 0.0658176, 'divForward': 0.426953, 'divBackward': 0.426083, 'divCentered': 0.172978, 'divDirectForward': 0.326537, 'divDirectBackward': 0.326581, 'divDirectCentered': 0.078853, 'forwardLap': 0.100776, 'backwardLap': 0.100776, 'centeredLap': 0.237975, 'directLap': 0.0660283, 'directLap_bc_along': 0.0660283, 'invForwardLap': 0.000983133, 'invBackwardLap': 0.000983133, 'invCenteredLap': 0.00241931, 'directLapST': 0.0659839}}
# {'n': 3, 'Nx': 80, 'Ny': 80, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.0830869, 'backward': 0.0830894, 'forward2': 0.0143987, 'backward2': 0.014507, 'centered': 0.00535835, 'dss': 0.0788619, 'centered_bc_along': 0.00535835, 'dss_bc_along': 0.0788619, 'divForward': 1.07103, 'divBackward': 1.07077, 'divCentered': 0.163243, 'divDirectForward': 0.083036, 'divDirectBackward': 0.0830385, 'divDirectCentered': 0.00535309, 'forwardLap': 0.0887295, 'backwardLap': 0.0887295, 'centeredLap': 0.162614, 'directLap': 0.0788942, 'directLap_bc_along': 0.0788942, 'invForwardLap': 0.000621173, 'invBackwardLap': 0.000621173, 'invCenteredLap': 0.00156549, 'directLapST': 0.0788962}}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.16539, 'backward': 0.165407, 'forward2': 0.043075, 'backward2': 0.043247, 'centered': 0.0207324, 'dss': 0.0538984, 'centered_bc_along': 0.0207324, 'dss_bc_along': 0.0538984, 'divForward': 0.562893, 'divBackward': 0.561694, 'divCentered': 0.162801, 'divDirectForward': 0.165288, 'divDirectBackward': 0.165306, 'divDirectCentered': 0.0207131, 'forwardLap': 0.0856254, 'backwardLap': 0.0856254, 'centeredLap': 0.167044, 'directLap': 0.053933, 'directLap_bc_along': 0.053933, 'invForwardLap': 0.000780312, 'invBackwardLap': 0.000780312, 'invCenteredLap': 0.00168762, 'directLapST': 0.0539348}}

# %%
content = db.table()
df = pd.json_normalize(content)
df
# Out:
#      Nx   Ny  Nz  method  mx  my  n
# 0   160  160  80  linear  10  10  3
# 1    40   40  20  linear   1   1  3
# 2    40   40  40      dg  10  10  3
# 3    16   16  10      dg  10  10  3
# 4    10   10   5      dg  10  10  3
# 5    10   10   5      dg   1   1  3
# 6    10   10   5   cubic  10  10  3
# 7    80   80  40  linear   1   1  3
# 8    10   10   5   cubic   1   1  3
# 9    16   16  10   cubic  10  10  3
# 10   40   40  40   cubic   1   1  3
# 11   26   26  20      dg  10  10  3
# 12   64   64  80   cubic   1   1  3
# 13   64   64  80      dg   1   1  3
# 14   10   10   5  linear   1   1  3
# 15   20   20  10  linear   1   1  3
# 16   26   26  20   cubic  10  10  3
# 17   10   10   5  linear  10  10  3
# 18   26   26  20   cubic   1   1  3
# 19   26   26  20      dg   1   1  3
# 20   20   20  10  linear  10  10  3
# 21   40   40  40   cubic  10  10  3
# 22   64   64  80      dg  10  10  3
# 23  160  160  80  linear   1   1  3
# 24   80   80  40  linear  10  10  3
# 25   40   40  40      dg   1   1  3
# 26   16   16  10      dg   1   1  3
# 27   64   64  80   cubic  10  10  3
# 28   16   16  10   cubic   1   1  3
# 29   40   40  20  linear  10  10  3

# %%
table=list()
for data in content :
    with open( db.outfile( data)) as f:
        output = yaml.full_load(f)
        table.append( output)
df = pd.json_normalize(table)
df
# Out:
#     n   Nx   Ny  Nz  mx  my  method  Guenther.forward  Guenther.backward  \
# 0   3  160  160  80  10  10  linear          4.17e-02           4.17e-02
# 1   3   40   40  20   1   1  linear          1.65e-01           1.66e-01
# 2   3   40   40  40  10  10      dg          8.26e-02           8.26e-02
# 3   3   16   16  10  10  10      dg          3.26e-01           3.26e-01
# 4   3   10   10   5  10  10      dg          6.24e-01           6.24e-01
# 5   3   10   10   5   1   1      dg          6.24e-01           6.24e-01
# 6   3   10   10   5  10  10   cubic          6.24e-01           6.24e-01
# 7   3   80   80  40   1   1  linear          8.32e-02           8.33e-02
# 8   3   10   10   5   1   1   cubic          6.24e-01           6.24e-01
# 29                     5.39e-02                7.80e-04
#
#     Guenther.invBackwardLap  Guenther.invCenteredLap  Guenther.directLapST
# 0                  4.17e-04                 1.38e-03              1.14e-01
# 1                  1.50e-03                 2.20e-03              5.24e-02
# 2                  4.48e-05                 1.53e-04              3.94e-03
# 3                  5.76e-04                 1.95e-03              5.83e-02
# 4                  1.95e-03                 5.25e-03              1.93e-01
# 5                  2.38e-03                 5.40e-03              1.93e-01
# 6                  2.07e-03                 5.32e-03              1.93e-01
# 7                  1.94e-03                 3.12e-03              6.97e-02
# 8                  2.30e-03                 5.41e-03              1.93e-01
# 9                  9.64e-04                 2.41e-03              5.83e-02
# 10                 1.68e-03                 2.82e-03              3.94e-03
# 11                 1.51e-04                 5.76e-04              1.55e-02
# 12                 1.41e-03                 2.69e-03              9.90e-04
# 13                 3.50e-03                 6.49e-03              9.95e-04
# 14                 2.23e-03                 5.38e-03              1.95e-01
# 15                 1.30e-03                 2.58e-03              6.77e-02
# 16                 7.54e-04                 1.69e-03              1.55e-02
# 17                 2.09e-03                 5.34e-03              1.94e-01
# 18                 1.20e-03                 1.97e-03              1.55e-02
# 19                 3.04e-03                 3.35e-03              1.55e-02
# 20                 9.83e-04                 2.42e-03              6.60e-02
# 21                 5.86e-04                 1.58e-03              3.94e-03
# 22                 4.44e-05                 7.01e-05              9.91e-04
# 23                 2.01e-03                 4.79e-03              9.70e-02
# 24                 6.21e-04                 1.57e-03              7.89e-02
# 25                 6.67e-03                 7.68e-03              3.94e-03
# 26                 1.52e-03                 2.47e-03              5.83e-02
# 27                 3.79e-04                 1.38e-03              9.90e-04
# 28                 1.19e-03                 2.52e-03              5.83e-02
# 29                 7.80e-04                 1.69e-03              5.39e-02
#
# [30 rows x 30 columns]

# %%
m = 10
method = "linear"
names = ["centered", "dss", "divCentered", "invCenteredLap"]
#names = ["centered_bc_along", "dss_bc_along", "divCentered", "invCenteredLap"]
columns = []
for name in names :
    columns.append( "Guenther."+name)
df_dir = df[["method", "mx", "Nx", "Nz"]+columns]
df_dir = df_dir.loc [ df_dir["mx"]==m]
df_dir = df_dir.loc[ df_dir["method"] == method]
df_dir = df_dir.sort_values( by=['mx','Nx','Nz']) # sort
for name in names:
    df_dir.insert(df_dir.columns.get_loc("Guenther."+name)+1,column="order."+name,
                  value=df_dir.loc[:,"Guenther."+name])
    df_dir["order."+name] = (np.log ( df_dir["order."+name]/ df_dir["order."+name].shift(1))/
        np.log( df_dir["Nz"].shift(1)/df_dir["Nz"]))
df_dir.set_index(['method','mx','Nx','Nz'], inplace=True)
headers = [ "$\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}",
            "$\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}",
            "$\nabla \cdot ( {\mathbf{\hat b}} f)$",
            "$\Delta_\parallel^{-1} f$"]
df_dir.columns=pd.MultiIndex.from_product([headers,["error", "order"] ])
df_dir
# Out:
#                  $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}           \
#                                                          error    order
# method mx Nx  Nz
# linear 10 10  5                                       2.79e-01      nan
#           20  10                                      7.89e-02 1.82e+00
#           40  20                                      2.07e-02 1.93e+00
#           80  40                                      5.36e-03 1.95e+00
#           160 80                                      1.47e-03 1.87e+00
#
#                  $\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}            \
#                                                             error     order
# method mx Nx  Nz
# linear 10 10  5                                          1.94e-01       nan
#           20  10                                         6.58e-02  1.56e+00
#           40  20                                         5.39e-02  2.88e-01
#           80  40                                         7.89e-02 -5.49e-01
#           160 80                                         1.14e-01 -5.30e-01
#
#                  $\nabla \cdot ( {\mathbf{\hat b}} f)$            \
#                                                  error     order
# method mx Nx  Nz
# linear 10 10  5                               3.06e-01       nan
#           20  10                              1.73e-01  8.23e-01
#           40  20                              1.63e-01  8.75e-02
#           80  40                              1.63e-01 -3.91e-03
#           160 80                              1.64e-01 -8.84e-03
#
#                  $\Delta_\parallel^{-1} f$
#                                      error    order
# method mx Nx  Nz
# linear 10 10  5                   5.34e-03      nan
#           20  10                  2.42e-03 1.14e+00
#           40  20                  1.69e-03 5.20e-01
#           80  40                  1.57e-03 1.08e-01
#           160 80                  1.38e-03 1.85e-01

# %%
#define conversion function 
def orderToString(x): 
    if np.isnan(x) : return 'n/a'
    return'%.2f'% x

def errorToString(x):
    return '%.2e' % x

# %%
string_df_dir = df_dir
for header in headers :  
    string_df_dir[header, "error"]=string_df_dir[header, "error"].apply( errorToString)
    string_df_dir[header, "order"]=string_df_dir[header, "order"].apply( orderToString)
string_df_dir
# Out:
#                  $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                          error order
# method mx Nx  Nz
# linear 10 10  5                                       2.79e-01   n/a
#           20  10                                      7.89e-02  1.82
#           40  20                                      2.07e-02  1.93
#           80  40                                      5.36e-03  1.95
#           160 80                                      1.47e-03  1.87
#
#                  $\nabla^2_\parallel$ Eq.~\eqref{eq:second_order}         \
#                                                             error  order
# method mx Nx  Nz
# linear 10 10  5                                          1.94e-01    n/a
#           20  10                                         6.58e-02   1.56
#           40  20                                         5.39e-02   0.29
#           80  40                                         7.89e-02  -0.55
#           160 80                                         1.14e-01  -0.53
#
#                  $\nabla \cdot ( {\mathbf{\hat b}} f)$         \
#                                                  error  order
# method mx Nx  Nz
# linear 10 10  5                               3.06e-01    n/a
#           20  10                              1.73e-01   0.82
#           40  20                              1.63e-01   0.09
#           80  40                              1.63e-01  -0.00
#           160 80                              1.64e-01  -0.01
#
#                  $\Delta_\parallel^{-1} f$
#                                      error order
# method mx Nx  Nz
# linear 10 10  5                   5.34e-03   n/a
#           20  10                  2.42e-03  1.14
#           40  20                  1.69e-03  0.52
#           80  40                  1.57e-03  0.11
#           160 80                  1.38e-03  0.18

# %%
filename='ds_guennther'+str(m)+'.tex'
with open(filename, 'wb') as f:
    f.write(bytes(df_dir.to_latex(
        escape=False,column_format='llllp{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}',
                               bold_rows=True),'UTF-8'))
