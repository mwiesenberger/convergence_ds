# %%
import json
import simplesimdb as database
import yaml
import numpy as np
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
# Create Database manger
db = database.Manager( directory = 'data_ds_guenther_t',
        filetype='yaml', executable='./execute_guenther.sh')
# db.delete_all()

# %%
# First generate some data
support=[1,10]
methods=["dg","linear", "cubic"]
resolutionDG = [ (10,5), (16,10), (26,20), (40,40), (64,80) ]#, (100,160)]
resolutionL =  [ (10,5), (20,10), (40,20), (80,40), (160,80) ]#, (100,160)]
# create simulation database
for method in methods :
    for m in support :
        if ( method == "linear"):
            for n in resolutionL :
                inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                    "mx" : m, "my" : m, "method" : method }
                print( inputfile)
                db.create( inputfile)  
        else :
            for n in resolutionDG :
                inputfile = { "n": 3, "Nx" : n[0], "Ny" : n[0], "Nz" : n[1],
                    "mx" : m, "my" : m, "method" : method }
                print( inputfile)
                db.create( inputfile, error="display")
# Out:
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'dg'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'dg'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 20, 'Ny': 20, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 80, 'Ny': 80, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 160, 'Ny': 160, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'linear'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 20, 'Ny': 20, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 80, 'Ny': 80, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 160, 'Ny': 160, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'linear'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'cubic'}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 16, 'Ny': 16, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 26, 'Ny': 26, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'cubic'}
# {'n': 3, 'Nx': 64, 'Ny': 64, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'cubic'}

# %%
content = db.table()
for entry in content:
    if entry["mx"] == 10 and entry["method"] == "linear":
        with open( db.outfile( entry) ) as f:
            output = yaml.full_load(f)
            print( output)
# Out:
# {'n': 3, 'Nx': 80, 'Ny': 80, 'Nz': 40, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.0830535, 'forward_vol': -0.000995993, 'backward': 0.0830596, 'backward_vol': 0.000948568, 'forward2': 0.0141024, 'forward2_vol': -0.000931992, 'backward2': 0.0142604, 'backward2_vol': 0.0010107, 'centered': 0.00535629, 'centered_vol': -2.37125e-05, 'dss': 0.0788628, 'dss_vol': -0.000812169, 'centered_bc_along': 0.00535629, 'centered_bc_along_vol': -2.37125e-05, 'dss_bc_along': 0.0788628, 'dss_bc_along_vol': -0.000812169, 'divForward': 0.0831854, 'divForward_vol': -0.000721698, 'divBackward': 0.0832009, 'divBackward_vol': 0.00071319, 'divCentered': 0.00540858, 'divCentered_vol': -4.2544e-06, 'directLap': 0.0789005, 'directLap_vol': -0.000739275, 'invCenteredLap': 0.000539312, 'invCenteredLap_vol': 20.9435, 'centeredST': 0.00536593}, 'volume_error': {'minus': 1.84331e-14, 'plus': 1.84331e-14, 'Inv': 0.101838}}
# {'n': 3, 'Nx': 40, 'Ny': 40, 'Nz': 20, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.165322, 'forward_vol': -0.0019716, 'backward': 0.165348, 'backward_vol': 0.00180029, 'forward2': 0.0426753, 'forward2_vol': -0.00173435, 'backward2': 0.0429338, 'backward2_vol': 0.00206388, 'centered': 0.0207219, 'centered_vol': -8.56543e-05, 'dss': 0.0538894, 'dss_vol': -0.000782409, 'centered_bc_along': 0.0207219, 'centered_bc_along_vol': -8.56543e-05, 'dss_bc_along': 0.0538894, 'dss_bc_along_vol': -0.000782409, 'divForward': 0.165579, 'divForward_vol': -0.00139664, 'divBackward': 0.165632, 'divBackward_vol': 0.0013802, 'divCentered': 0.0209286, 'divCentered_vol': -8.22134e-06, 'directLap': 0.0538962, 'directLap_vol': -0.000713191, 'invCenteredLap': 0.000485552, 'invCenteredLap_vol': 20.9433, 'centeredST': 0.0207795}, 'volume_error': {'minus': 1.15246e-12, 'plus': 1.15246e-12, 'Inv': 0.102628}}
# {'n': 3, 'Nx': 20, 'Ny': 20, 'Nz': 10, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.326599, 'forward_vol': -0.00394941, 'backward': 0.326666, 'backward_vol': 0.00341971, 'forward2': 0.155111, 'forward2_vol': -0.00305278, 'backward2': 0.155391, 'backward2_vol': 0.00437655, 'centered': 0.0788652, 'centered_vol': -0.000264849, 'dss': 0.0656723, 'dss_vol': -0.00076907, 'centered_bc_along': 0.0788652, 'centered_bc_along_vol': -0.000264849, 'dss_bc_along': 0.0656723, 'dss_bc_along_vol': -0.00076907, 'divForward': 0.327074, 'divForward_vol': -0.00274713, 'divBackward': 0.327219, 'divBackward_vol': 0.00282319, 'divCentered': 0.0795886, 'divCentered_vol': 3.8029e-05, 'directLap': 0.0653574, 'directLap_vol': -0.000714202, 'invCenteredLap': 0.000646243, 'invCenteredLap_vol': 20.9433, 'centeredST': 0.0793289}, 'volume_error': {'minus': 2.29215e-11, 'plus': 2.29215e-11, 'Inv': 0.103969}}
# {'n': 3, 'Nx': 160, 'Ny': 160, 'Nz': 80, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.0417069, 'forward_vol': -0.000499555, 'backward': 0.041715, 'backward_vol': 0.000487706, 'forward2': 0.00735339, 'forward2_vol': -0.000488373, 'backward2': 0.00748001, 'backward2_vol': 0.000508184, 'centered': 0.00146878, 'centered_vol': -5.92448e-06, 'dss': 0.113866, 'dss_vol': -0.000828304, 'centered_bc_along': 0.00146878, 'centered_bc_along_vol': -5.92448e-06, 'dss_bc_along': 0.113866, 'dss_bc_along_vol': -0.000828304, 'divForward': 0.0417731, 'divForward_vol': -0.000366448, 'divBackward': 0.0417849, 'divBackward_vol': 0.00036434, 'divCentered': 0.00148058, 'divCentered_vol': -1.05395e-06, 'directLap': 0.113916, 'directLap_vol': -0.000754414, 'invCenteredLap': 0.000450442, 'invCenteredLap_vol': 20.9437, 'centeredST': 0.00142905}, 'volume_error': {'minus': 2.26173e-16, 'plus': 2.26173e-16, 'Inv': 0.101376}}
# {'n': 3, 'Nx': 10, 'Ny': 10, 'Nz': 5, 'mx': 10, 'my': 10, 'method': 'linear', 'Guenther': {'forward': 0.624553, 'forward_vol': -0.00778957, 'backward': 0.624792, 'backward_vol': 0.00548652, 'forward2': 0.526968, 'forward2_vol': -0.00453456, 'backward2': 0.527437, 'backward2_vol': 0.00704926, 'centered': 0.278507, 'centered_vol': -0.00115153, 'dss': 0.193417, 'dss_vol': -0.000712247, 'centered_bc_along': 0.278507, 'centered_bc_along_vol': -0.00115153, 'dss_bc_along': 0.193417, 'dss_bc_along_vol': -0.000712247, 'divForward': 0.625289, 'divForward_vol': -0.00550914, 'divBackward': 0.625723, 'divBackward_vol': 0.00540758, 'divCentered': 0.280091, 'divCentered_vol': -5.07798e-05, 'directLap': 0.1922, 'directLap_vol': -0.000702021, 'invCenteredLap': 0.00195512, 'invCenteredLap_vol': 20.9433, 'centeredST': 0.280409}, 'volume_error': {'minus': 2.87579e-10, 'plus': 2.87579e-10, 'Inv': 0.109863}}

# %%
content = db.table()
df = pd.json_normalize(content)
df
# Out:
#      Nx   Ny  Nz  method  mx  my  n
# 0    64   64  80      dg  10  10  3
# 1    10   10   5  linear   1   1  3
# 2    40   40  40      dg   1   1  3
# 3    10   10   5      dg   1   1  3
# 4    80   80  40  linear   1   1  3
# 5    80   80  40  linear  10  10  3
# 6    40   40  20  linear  10  10  3
# 7    10   10   5   cubic  10  10  3
# 8    10   10   5      dg  10  10  3
# 9    26   26  20      dg   1   1  3
# 10  160  160  80  linear   1   1  3
# 11   64   64  80   cubic  10  10  3
# 12   20   20  10  linear  10  10  3
# 13   40   40  40   cubic  10  10  3
# 14   26   26  20      dg  10  10  3
# 15   10   10   5   cubic   1   1  3
# 16   16   16  10      dg  10  10  3
# 17   16   16  10      dg   1   1  3
# 18   16   16  10   cubic  10  10  3
# 19   64   64  80      dg   1   1  3
# 20   40   40  40      dg  10  10  3
# 21  160  160  80  linear  10  10  3
# 22   64   64  80   cubic   1   1  3
# 23   40   40  40   cubic   1   1  3
# 24   20   20  10  linear   1   1  3
# 25   26   26  20   cubic   1   1  3
# 26   26   26  20   cubic  10  10  3
# 27   10   10   5  linear  10  10  3
# 28   16   16  10   cubic   1   1  3
# 29   40   40  20  linear   1   1  3

# %%
table=list()
for data in content :
    with open( db.outfile( data)) as f:
        output = yaml.full_load(f)
        table.append( output)
df = pd.json_normalize(table)
df
# Out:
#     n   Nx   Ny  Nz  mx  my  method  Guenther.forward  Guenther.forward_vol  \
# 0   3   64   64  80  10  10      dg          4.13e-02             -1.33e-04
# 1   3   10   10   5   1   1  linear          6.24e-01             -7.21e-03
# 2   3   40   40  40   1   1      dg          8.26e-02             -2.74e-04
# 3   3   10   10   5   1   1      dg          6.23e-01             -2.33e-03
# 4   3   80   80  40   1   1  linear          8.31e-02             -1.03e-03
# 5   3   80   80  40  10  10  linear          8.31e-02             -9.96e-04
# 6   3   40   40  20  10  10  linear          1.65e-01             -1.97e-03
# 7   3   10   10   5  10  10   cubic          6.23e-01             -2.33e-03
# 8   3   10   10   5  10  10      dg          6.23e-01             -2.33e-03
# 9   3   26   26  20   1   1      dg          1.65e-01             -5.76e-04
# 10  3  160  160  80   1   1  linear          4.18e-02             -5.27e-04
# 11  3   64   64  80  10  10   cubic          4.13e-02             -1.33e-04
# 12  3   20   20  10  10  10  linear          3.27e-01             -3.95e-03
# 13  3   40   40  40  10  10   cubic          8.26e-02             -2.74e-04
# 14  3   26   26  20  10  10      dg          1.65e-01             -5.76e-04
# 15  3   10   10   5   1   1   cubic          6.23e-01             -2.33e-03
# 16  3   16   16  10  10  10      dg          3.26e-01             -1.21e-03
# 17  3   16   16  10   1   1      dg          3.26e-01             -1.21e-03
# 18  3   16   16  10  10  10   cubic          3.26e-01             -1.21e-03
# 19  3   64   64  80   1   1      dg          4.13e-02             -1.33e-04
# 20  3   40   40  40  10  10      dg          8.26e-02             -2.74e-04
# 21  3  160  160  80  10  10  linear          4.17e-02             -5.00e-04
# 22  3   64   64  80   1   1   cubic          4.13e-02             -1.33e-04
# 23  3   40   40  40   1   1   cubic          8.26e-02             -2.74e-04
# 24  3   20   20  10   1   1  linear          3.27e-01             -3.34e-03
# 25  3   26   26  20   1   1   cubic          1.65e-01             -5.76e-04
# 26  3   26   26  20  10  10   cubic          1.65e-01             -5.76e-04
# 27  3   10   10   5  10  10  linear          6.25e-01             -7.79e-03
# 28  3   16   16  10   1   1   cubic          3.26e-01             -1.21e-03
# 29  3   40   40  20   1   1  linear          1.65e-01             -1.96e-03
#
#     Guenther.backward  ...  Guenther.divCentered  Guenther.divCentered_vol  \
# 0            4.13e-02  ...              1.29e-03                  4.76e-14
# 22           2.26e-16          2.21e-01
# 23           1.85e-14          2.21e-01
# 24           2.29e-11          2.94e-01
# 25           1.15e-12          2.51e-01
# 26           1.15e-12          1.07e-01
# 27           2.88e-10          1.10e-01
# 28           2.35e-11          3.05e-01
# 29           1.15e-12          2.70e-01
#
# [30 rows x 37 columns]

# %%
m = 10
method = "dg"
names = ["centered", "directLap", "directLap_vol", "divCentered", "divCentered_vol", "invCenteredLap"]
columns = []
for name in names :
    columns.append( "Guenther."+name)
df_dir = df[["method", "mx", "Nx", "Nz"]+columns]
df_dir = df_dir.loc [ df_dir["mx"]==m]
df_dir = df_dir.loc[ df_dir["method"] == method]
df_dir = df_dir.sort_values( by=['mx','Nx','Nz']) # sort
for name in names:
    df_dir.insert(df_dir.columns.get_loc("Guenther."+name)+1,column="order."+name,
                  value=df_dir.loc[:,"Guenther."+name])
    df_dir["order."+name] = (np.log ( np.abs(df_dir["order."+name]/ df_dir["order."+name].shift(1)))/
        np.log( df_dir["Nz"].shift(1)/df_dir["Nz"]))
df_dir.set_index(['method','mx','Nx','Nz'], inplace=True)
headers = [ "$\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}",
            "$\Delta_\parallel$ Eq.~\eqref{eq:second_order}",
            "$\int dV \Delta_\parallel f / ||f||_2$",
            "$\nabla \cdot ( {\mathbf{\hat b}} f)$",
            "$\int dV \nabla \cdot ( {\mathbf{\hat b}} f) / ||f||_2$",
            "$(1-\Delta_\parallel)^{-1} f$"]
df_dir.columns=pd.MultiIndex.from_product([headers,["error", "order"] ])
df_dir
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}           \
#                                                         error    order
# method mx Nx Nz
# dg     10 10 5                                       2.77e-01      nan
#           16 10                                      7.79e-02 1.83e+00
#           26 20                                      2.02e-02 1.95e+00
#           40 40                                      5.10e-03 1.99e+00
#           64 80                                      1.28e-03 2.00e+00
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}           \
#                                                          error    order
# method mx Nx Nz
# dg     10 10 5                                        1.91e-01      nan
#           16 10                                       5.76e-02 1.73e+00
#           26 20                                       1.53e-02 1.91e+00
#           40 40                                       3.89e-03 1.98e+00
#           64 80                                       9.78e-04 1.99e+00
#
#                 $\int dV \Delta_\parallel f / ||f||_2$            \
#                                                  error     order
# method mx Nx Nz
# dg     10 10 5                                3.77e-07       nan
#           16 10                              -7.40e-09  5.67e+00
#           26 20                              -1.06e-08 -5.19e-01
#           40 40                              -1.14e-09  3.22e+00
#           64 80                              -7.11e-11  4.00e+00
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$           \
#                                                 error    order
# method mx Nx Nz
# dg     10 10 5                               2.78e-01      nan
#           16 10                              7.87e-02 1.82e+00
#           26 20                              2.04e-02 1.95e+00
#           40 40                              5.16e-03 1.99e+00
#           64 80                              1.29e-03 2.00e+00
#
#                 $\int dV \nabla \cdot ( {\mathbf{\hat b}} f) / ||f||_2$  \
#                                                                   error
# method mx Nx Nz
# dg     10 10 5                                            1.41e-06
#           16 10                                          -1.59e-08
#           26 20                                          -2.93e-09
#           40 40                                           1.18e-12
#           64 80                                           4.76e-14
#
#                          $(1-\Delta_\parallel)^{-1} f$
#                    order                         error    order
# method mx Nx Nz
# dg     10 10 5       nan                      1.95e-03      nan
#           16 10 6.47e+00                      5.72e-04 1.77e+00
#           26 20 2.44e+00                      1.50e-04 1.93e+00
#           40 40 1.13e+01                      3.79e-05 1.98e+00
#           64 80 4.64e+00                      9.49e-06 2.00e+00

# %%
#define conversion function 
def orderToString(x): 
    if np.isnan(x) : return 'n/a'
    return'%.2f'% x

def errorToString(x):
    return '%.2e' % x

# %%
string_df_dir = df_dir
for header in headers :  
    string_df_dir[header, "error"]=string_df_dir[header, "error"].apply( errorToString)
    string_df_dir[header, "order"]=string_df_dir[header, "order"].apply( orderToString)
string_df_dir
# Out:
#                 $\nabla_\parallel$ Eq.~\eqref{eq:paralleldis}        \
#                                                         error order
# method mx Nx Nz
# dg     10 10 5                                       2.77e-01   n/a
#           16 10                                      7.79e-02  1.83
#           26 20                                      2.02e-02  1.95
#           40 40                                      5.10e-03  1.99
#           64 80                                      1.28e-03  2.00
#
#                 $\Delta_\parallel$ Eq.~\eqref{eq:second_order}        \
#                                                          error order
# method mx Nx Nz
# dg     10 10 5                                        1.91e-01   n/a
#           16 10                                       5.76e-02  1.73
#           26 20                                       1.53e-02  1.91
#           40 40                                       3.89e-03  1.98
#           64 80                                       9.78e-04  1.99
#
#                 $\int dV \Delta_\parallel f / ||f||_2$         \
#                                                  error  order
# method mx Nx Nz
# dg     10 10 5                                3.77e-07    n/a
#           16 10                              -7.40e-09   5.67
#           26 20                              -1.06e-08  -0.52
#           40 40                              -1.14e-09   3.22
#           64 80                              -7.11e-11   4.00
#
#                 $\nabla \cdot ( {\mathbf{\hat b}} f)$        \
#                                                 error order
# method mx Nx Nz
# dg     10 10 5                               2.78e-01   n/a
#           16 10                              7.87e-02  1.82
#           26 20                              2.04e-02  1.95
#           40 40                              5.16e-03  1.99
#           64 80                              1.29e-03  2.00
#
#                 $\int dV \nabla \cdot ( {\mathbf{\hat b}} f) / ||f||_2$  \
#                                                                   error
# method mx Nx Nz
# dg     10 10 5                                            1.41e-06
#           16 10                                          -1.59e-08
#           26 20                                          -2.93e-09
#           40 40                                           1.18e-12
#           64 80                                           4.76e-14
#
#                        $(1-\Delta_\parallel)^{-1} f$
#                  order                         error order
# method mx Nx Nz
# dg     10 10 5     n/a                      1.95e-03   n/a
#           16 10   6.47                      5.72e-04  1.77
#           26 20   2.44                      1.50e-04  1.93
#           40 40  11.28                      3.79e-05  1.98
#           64 80   4.64                      9.49e-06  2.00

# %%
filename='ds_guenther'+str(m)+'.tex'
with open(filename, 'wb') as f:
    f.write(bytes(df_dir.to_latex(
        escape=False,column_format='llllp{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}',
                               bold_rows=True),'UTF-8'))
