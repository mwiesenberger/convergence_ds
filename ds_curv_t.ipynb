# %%
import json
import simplesimdb as database
import yaml
import numpy as np
import pandas as pd

pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
#define conversion function 
def orderToString(x): 
    if np.isnan(x) : return 'n/a'
    return'%.2f'% x

def errorToString(x):
    return '%.2e' % x

# %%
# db.delete_all()

# %%
# Create Database manger
db = database.Manager( directory = 'data_ds_curv_t',
        filetype='yaml', executable='./execute_curv.sh')

# %%
# First generate some data
support=[1,10,100]
methods=["dg","linear"]
resolutionDG = [ (10,5), (20,10), (40,20), (80,40), (160,80) ]#, (100,160)]
resolutionL =  [ (10,5), (20,10), (40,20), (80,40), (160,80) ]#, (100,160)]
# create simulation database
for method in methods :
    for m in support :
        if ( method == "linear"):
            for n in resolutionL :
                inputfile = { "n": 3, "Nx" : 8, "Ny" : n[0], "Nz" : n[1],
                    "mx" : 1, "my" : m, "method" : method }
                print( inputfile)
                db.create( inputfile)  
        else :
            for n in resolutionDG :
                inputfile = { "n": 3, "Nx" : 8, "Ny" : n[0], "Nz" : n[1],
                    "mx" : 1, "my" : m, "method" : method }
                print( inputfile)
                db.create( inputfile, error="display")
# Out:
# {'n': 3, 'Nx': 8, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation a8d81c...9e47.yaml
# {'n': 3, 'Nx': 8, 'Ny': 20, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation 17cb05...5620.yaml
# {'n': 3, 'Nx': 8, 'Ny': 40, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation 50e658...3e46.yaml
# {'n': 3, 'Nx': 8, 'Ny': 80, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation 6b9d0f...73c0.yaml
# {'n': 3, 'Nx': 8, 'Ny': 160, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'dg'}
# Running simulation b113b9...b8e2.yaml
# {'n': 3, 'Nx': 8, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 10, 'method': 'dg'}
# Running simulation c4a168...29ff.yaml
# {'n': 3, 'Nx': 8, 'Ny': 20, 'Nz': 10, 'mx': 1, 'my': 10, 'method': 'dg'}
# Running simulation 64d713...fb29.yaml
# {'n': 3, 'Nx': 8, 'Ny': 40, 'Nz': 20, 'mx': 1, 'my': 10, 'method': 'dg'}
# Running simulation 8f9b59...9170.yaml
# {'n': 3, 'Nx': 8, 'Ny': 80, 'Nz': 40, 'mx': 1, 'my': 10, 'method': 'dg'}
# Running simulation 83344a...4193.yaml
# {'n': 3, 'Nx': 8, 'Ny': 160, 'Nz': 80, 'mx': 1, 'my': 10, 'method': 'dg'}
# Running simulation 80ee27...e9c6.yaml
# {'n': 3, 'Nx': 8, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 100, 'method': 'dg'}
# Running simulation bf5271...6f5a.yaml
# {'n': 3, 'Nx': 8, 'Ny': 20, 'Nz': 10, 'mx': 1, 'my': 100, 'method': 'dg'}
# Running simulation cadfd9...f9ff.yaml
# {'n': 3, 'Nx': 8, 'Ny': 40, 'Nz': 20, 'mx': 1, 'my': 100, 'method': 'dg'}
# Running simulation d1c5fe...ca3c.yaml
# {'n': 3, 'Nx': 8, 'Ny': 80, 'Nz': 40, 'mx': 1, 'my': 100, 'method': 'dg'}
# Running simulation b89273...63e6.yaml
# {'n': 3, 'Nx': 8, 'Ny': 160, 'Nz': 80, 'mx': 1, 'my': 100, 'method': 'dg'}
# Running simulation 47ce86...02dc.yaml
# {'n': 3, 'Nx': 8, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation 6ff1a5...3324.yaml
# {'n': 3, 'Nx': 8, 'Ny': 20, 'Nz': 10, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation b16252...9c20.yaml
# {'n': 3, 'Nx': 8, 'Ny': 40, 'Nz': 20, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation 5442eb...4154.yaml
# {'n': 3, 'Nx': 8, 'Ny': 80, 'Nz': 40, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation 0fb305...882c.yaml
# {'n': 3, 'Nx': 8, 'Ny': 160, 'Nz': 80, 'mx': 1, 'my': 1, 'method': 'linear'}
# Running simulation 59c875...53a3.yaml
# {'n': 3, 'Nx': 8, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 10, 'method': 'linear'}
# Running simulation d31e22...b2ec.yaml
# {'n': 3, 'Nx': 8, 'Ny': 20, 'Nz': 10, 'mx': 1, 'my': 10, 'method': 'linear'}
# Running simulation 816069...d556.yaml
# {'n': 3, 'Nx': 8, 'Ny': 40, 'Nz': 20, 'mx': 1, 'my': 10, 'method': 'linear'}
# Running simulation 75a865...c824.yaml
# {'n': 3, 'Nx': 8, 'Ny': 80, 'Nz': 40, 'mx': 1, 'my': 10, 'method': 'linear'}
# Running simulation 80a169...44d5.yaml
# {'n': 3, 'Nx': 8, 'Ny': 160, 'Nz': 80, 'mx': 1, 'my': 10, 'method': 'linear'}
# Running simulation 91d465...3afd.yaml
# {'n': 3, 'Nx': 8, 'Ny': 10, 'Nz': 5, 'mx': 1, 'my': 100, 'method': 'linear'}
# Running simulation cb9c3a...275e.yaml
# {'n': 3, 'Nx': 8, 'Ny': 20, 'Nz': 10, 'mx': 1, 'my': 100, 'method': 'linear'}
# Running simulation 01ecd8...aa9d.yaml
# {'n': 3, 'Nx': 8, 'Ny': 40, 'Nz': 20, 'mx': 1, 'my': 100, 'method': 'linear'}
# Running simulation ec8061...146c.yaml
# {'n': 3, 'Nx': 8, 'Ny': 80, 'Nz': 40, 'mx': 1, 'my': 100, 'method': 'linear'}
# Running simulation 4becb6...3502.yaml
# {'n': 3, 'Nx': 8, 'Ny': 160, 'Nz': 80, 'mx': 1, 'my': 100, 'method': 'linear'}
# Running simulation 552a54...f7f1.yaml

# %%
content = db.table()
for entry in content:
    if entry["mx"] == 10 and entry["method"] == "linear":
        with open( db.outfile( entry) ) as f:
            output = yaml.full_load(f)
            print( output)

# %%
content = db.table()
df = pd.json_normalize(content)
df
# Out:
#     Nx   Ny  Nz  method  mx   my  n
# 0    8   20  10      dg   1   10  3
# 1    8   20  10      dg   1    1  3
# 2    8   40  20  linear   1    1  3
# 3    8   10   5      dg   1  100  3
# 4    8   20  10      dg   1  100  3
# 5    8   10   5  linear   1    1  3
# 6    8   10   5  linear   1   10  3
# 7    8   20  10  linear   1  100  3
# 8    8   40  20      dg   1    1  3
# 9    8   80  40  linear   1    1  3
# 10   8   10   5  linear   1  100  3
# 11   8  160  80  linear   1   10  3
# 12   8   80  40      dg   1  100  3
# 13   8   80  40      dg   1   10  3
# 14   8   80  40  linear   1  100  3
# 15   8   40  20      dg   1   10  3
# 16   8  160  80  linear   1  100  3
# 17   8  160  80      dg   1    1  3
# 18   8   40  20  linear   1  100  3
# 19   8   40  20  linear   1   10  3
# 20   8   40  20      dg   1  100  3
# 21   8   80  40      dg   1    1  3
# 22   8  160  80      dg   1   10  3
# 23   8   80  40  linear   1   10  3
# 24   8  160  80      dg   1  100  3
# 25   8  160  80  linear   1    1  3
# 26   8   20  10  linear   1    1  3
# 27   8   20  10  linear   1   10  3
# 28   8   10   5      dg   1    1  3
# 29   8   10   5      dg   1   10  3

# %%
table=list()
for data in content :
    with open( db.outfile( data)) as f:
        output = yaml.full_load(f)
        table.append( output)
df = pd.json_normalize(table)
df
# Out:
#     n  Nx   Ny  Nz  mx   my  method  Flux.forward  Flux.forward_vol  \
# 0   3   8   20  10   1   10      dg      6.29e-01          6.10e-02
# 1   3   8   20  10   1    1      dg      6.29e-01          5.87e-02
# 2   3   8   40  20   1    1  linear      3.29e-01          4.04e-02
# 3   3   8   10   5   1  100      dg      1.06e+00          3.74e-02
# 4   3   8   20  10   1  100      dg      6.29e-01          6.10e-02
# 5   3   8   10   5   1    1  linear      1.06e+00          3.11e-02
# 6   3   8   10   5   1   10  linear      1.06e+00          3.11e-02
# 7   3   8   20  10   1  100  linear      6.29e-01          5.88e-02
# 8   3   8   40  20   1    1      dg      3.29e-01          4.20e-02
# 9   3   8   80  40   1    1  linear      1.66e-01          2.34e-02
# 10  3   8   10   5   1  100  linear      1.06e+00          3.10e-02
# 11  3   8  160  80   1   10  linear      8.32e-02          1.27e-02
# 12  3   8   80  40   1  100      dg      1.66e-01          2.42e-02
# 13  3   8   80  40   1   10      dg      1.66e-01          2.42e-02
# 14  3   8   80  40   1  100  linear      1.66e-01          2.39e-02
# 15  3   8   40  20   1   10      dg      3.29e-01          4.22e-02
# 16  3   8  160  80   1  100  linear      8.32e-02          1.27e-02
# 17  3   8  160  80   1    1      dg      8.32e-02          1.28e-02
# 13            1.23e-06           1.23e-06
# 14            1.23e-06           1.23e-06
# 15            9.93e-06           9.75e-06
# 16            1.54e-07           1.54e-07
# 17            1.54e-07           1.54e-07
# 18            9.93e-06           9.75e-06
# 19            9.93e-06           9.75e-06
# 20            9.93e-06           9.75e-06
# 21            1.23e-06           1.23e-06
# 22            1.54e-07           1.54e-07
# 23            1.23e-06           1.23e-06
# 24            1.54e-07           1.54e-07
# 25            1.54e-07           1.54e-07
# 26            8.10e-05           7.65e-05
# 27            8.10e-05           7.65e-05
# 28            5.29e-04           6.61e-04
# 29            5.29e-04           6.61e-04
#
# [30 rows x 27 columns]

# %%
names = ["centered", "divCentered", "directLap", "divCentered_vol", "directLap_vol"]
columns = []
for name in names :
    columns.append( "Flux."+name)
dflist = []
string_mlist = []
string_methodlist = []
string_dflist = []
for method in ["dg","linear"]:
    for m in [1,10,100]:
        df_dir = df[["method", "my", "Ny", "Nz"]+columns]
        df_dir = df_dir.loc [ df_dir["my"]==m]
        df_dir = df_dir.loc[ df_dir["method"] == method]
        df_dir = df_dir.sort_values( by=['my','Ny','Nz']) # sort
        for name in names:
            df_dir.insert(df_dir.columns.get_loc("Flux."+name)+1,column="order."+name,
                          value=df_dir.loc[:,"Flux."+name])
            df_dir["order."+name] = (np.log ( np.abs(df_dir["order."+name]/ df_dir["order."+name].shift(1)))/
                np.log( df_dir["Nz"].shift(1)/df_dir["Nz"]))
        df_dir.drop(['method','my'],axis=1,inplace=True)
        df_dir.rename( columns={"Ny": r"$N_\eta$", "Nz": r"$N_\varphi$"},inplace=True)
        df_dir.set_index([r'$N_\eta$',r'$N_\varphi$'], inplace=True)
        headers = [ "$\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}",
                    "$\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}",
                    "$\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}",
                    "$\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $",
                    "$\int dV \Delta_\parallel^{CC} f $",
                    #"$\int dV F^+$",
                    #"$\int dV |\nabla_\perp F^+|$"
                  ]
        df_dir.columns=pd.MultiIndex.from_product([headers,["error", "order"] ])
        dflist.append(df_dir)
        string_df_dir = df_dir.copy()
        for header in headers :
            string_df_dir[header, "error"]=string_df_dir[header, "error"].apply( errorToString)
            string_df_dir[header, "order"]=string_df_dir[header, "order"].apply( orderToString)
        string_dflist.append(string_df_dir)
        string_methodlist.append( method)
        string_mlist.append(str(m))

# %%
for i in range(0,len(string_dflist)):
    display( string_dflist[i])
    print( "Method: ", string_methodlist[i])
    print( "my:     ", string_mlist[i])
    filename='ds_curv_'+string_methodlist[i]+string_mlist[i]+'.tex'
    with open(filename, 'wb') as f:
        f.write(bytes(string_dflist[i].to_latex(
            escape=False,column_format='llp{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}p{1.5cm}p{1.2cm}',
                                   bold_rows=True),'UTF-8'))
# Out:
#                      $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                                error order
# $N_\eta$ $N_\varphi$
# 10       5                                                  8.11e-01   n/a
# 20       10                                                 2.87e-01  1.50
# 40       20                                                 7.92e-02  1.86
# 80       40                                                 2.03e-02  1.96
# 160      80                                                 5.11e-03  1.99
#
#                      $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                                      error
# $N_\eta$ $N_\varphi$
# 10       5                                                     8.15e-01
# 20       10                                                    2.91e-01
# 40       20                                                    8.07e-02
# 80       40                                                    2.07e-02
# 160      80                                                    5.22e-03
#
#                            $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}  \
#                      order                                          error
# $N_\eta$ $N_\varphi$
# 10       5             n/a                                       4.98e-01
# 20       10           1.48                                       1.60e-01
# 40       20           1.85                                       4.30e-02
# 80       40           1.96                                       1.10e-02
# 160      80           1.99                                       2.76e-03
#
#                             \
#                      order
# $N_\eta$ $N_\varphi$
# 10       5             n/a
# 20       10           1.64
# 40       20           1
                              error  order
# $N_\eta$ $N_\varphi$
# 10       5              n/a                          -6.19e-07    n/a
# 20       10            0.46                          -1.62e-05  -4.71
# 40       20           -1.36                          -2.78e-05  -0.78
# 80       40            0.89                          -2.96e-05  -0.09
# 160      80            1.04                          -3.00e-05  -0.02
# Method:  linear
# my:      1
# <ipython-input-21-19bf5dbde70e>:7: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(bytes(string_dflist[i].to_latex(
#                      $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                                error order
# $N_\eta$ $N_\varphi$
# 10       5                                                  8.11e-01   n/a
# 20       10                                                 2.88e-01  1.50
# 40       20                                                 7.95e-02  1.86
# 80       40                                                 2.04e-02  1.96
# 160      80                                                 5.23e-03  1.97
#
#                      $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                                      error
# $N_\eta$ $N_\varphi$
# 10       5                                                     8.15e-01
# 20       10                                                    2.92e-01
# 40       20                                                    8.09e-02
# 80       40                                                    2.08e-02
# 160      80                                                    5.33e-03
#
#                            $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}  \
#                      order                                          error
# $N_\eta$ $N_\varphi$
# 10       5             n/a                                       4.99e-01
# 20       10           1.48                                       1.61e-01
# 40       20           1.85                                       4.33e-02
# 80       40           1.96                                       1.11e-02
# 160      80           1.97                                       2.95e-03
#
#                             \
#                      order
# $N_\eta$ $N_\varphi$
# 10       5             n/a
# 20       10           1.63
# 40       20           1.89
# 80       40           1.96
# 160      80           1.92
#
#                      $\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $  \
#                                                                    error
# $N_\eta$ $N_\varphi$
# 10       5                                                     2.81e-03
# 20       10                                                    1.51e-03
# 40       20                                                    6.30e-04
# 80       40                                                    3.03e-04
# 160      80                                                    1.51e-04
#
#                            $\int dV \Delta_\parallel^{CC} f $
#                      order                              error order
# $N_\eta$ $N_\varphi$
# 10       5             n/a                           4.42e-06   n/a
# 20       10           0.90                           4.40e-06  0.01
# 40       20           1.26                           2.22e-06  0.99
# 80       40           1.06                           1.24e-06  0.84
# 160      80           1.01                           7.76e-07  0.68
# Method:  linear
# my:      10
# <ipython-input-21-19bf5dbde70e>:7: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(bytes(string_dflist[i].to_latex(
#                      $\nabla_\parallel^{CC}$ Eq.~\eqref{eq:centered}        \
#                                                                error order
# $N_\eta$ $N_\varphi$
# 10       5                                                  8.11e-01   n/a
# 20       10                                                 2.88e-01  1.50
# 40       20                                                 7.95e-02  1.86
# 80       40                                                 2.04e-02  1.96
# 160      80                                                 5.23e-03  1.97
#
#                      $\nabla \cdot ( {\mathbf{\hat b}} f)^{CC}$ Eq.~\eqref{eq:divCentered}  \
#                                                                                      error
# $N_\eta$ $N_\varphi$
# 10       5                                                     8.15e-01
# 20       10                                                    2.92e-01
# 40       20                                                    8.09e-02
# 80       40                                                    2.08e-02
# 160      80                                                    5.33e-03
#
#                            $\Delta_\parallel^{CC}$ Eq.~\eqref{eq:laplace}  \
#                      order                                          error
# $N_\eta$ $N_\varphi$
# 10       5             n/a                                       4.99e-01
# 20       10           1.48                                       1.61e-01
# 40       20           1.85                                       4.33e-02
# 80       40           1.96                                       1.11e-02
# 160      80           1.97                                       2.95e-03
#
#                             \
#                      order
# $N_\eta$ $N_\varphi$
# 10       5             n/a
# 20       10           1.63
# 40       20           1.89
# 80       40           1.96
# 160      80           1.92
#
#                      $\int dV \nabla \cdot ( {\mathbf{\hat b}} f)^{CC} $  \
#                                                                    error
# $N_\eta$ $N_\varphi$
# 10       5                                                     2.79e-03
# 20       10                                                    1.52e-03
# 40       20                                                    6.29e-04
# 80       40                                                    3.04e-04
# 160      80                                                    1.51e-04
#
#                            $\int dV \Delta_\parallel^{CC} f $
#                      order                              error  order
# $N_\eta$ $N_\varphi$
# 10       5             n/a                           4.06e-06    n/a
# 20       10           0.88                           4.14e-06  -0.03
# 40       20           1.27                           1.95e-06   1.08
# 80       40           1.05                           9.74e-07   1.00
# 160      80           1.01                           4.88e-07   1.00
# Method:  linear
# my:      100
# <ipython-input-21-19bf5dbde70e>:7: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(bytes(string_dflist[i].to_latex(
